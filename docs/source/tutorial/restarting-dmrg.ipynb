# %% [markdown]
# # Restarting DMRG
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/block-hczhai/block2-preview/blob/master/docs/source/tutorial/restarting-dmrg.ipynb)

# %%
# !pip install block2==0.5.3rc5 -qq --progress-bar off --extra-index-url=https://block-hczhai.github.io/block2-preview/pypi/
# !pip install pyscf==2.3.0 -qq --progress-bar off

# %% [markdown]
# ## Introduction
#
# In this tutorial we explain how to restart a DMRG calculation using MPS stored in disk. When you use the ``pyblock2`` interface, the MPS data is automatically stored into the scratch folder so one can recover the calculation as long as the scratch data is not removed.

# %% [markdown]
# ## Restarting from Interruption
#
# One common case is that the DMRG calculation is interrupted by the ``Ctrl+C`` signal, or the job has reached the time limit. Let's say we have a normal DMRG, but interrupted in the middle of sweep 1 (counting from zero):

# %%
import numpy as np
from pyblock2._pyscf.ao2mo import integrals as itg
from pyblock2.driver.core import DMRGDriver, SymmetryTypes

from pyscf import gto, scf

mol = gto.M(atom='C 0 0 0; C 0 0 1.2425', basis='ccpvdz', symmetry='d2h')
mf = scf.RHF(mol).run(conv_tol=1E-14)
ncas, n_elec, spin, ecore, h1e, g2e, orb_sym = itg.get_rhf_integrals(mf,
    ncore=2, ncas=26, g2e_symm=8)

print("NCAS = %d NCASELEC = %d" % (ncas, n_elec))
driver = DMRGDriver(scratch="./tmp", symm_type=SymmetryTypes.SU2,
                    stack_mem=4 << 30, n_threads=4)
driver.initialize_system(n_sites=ncas, n_elec=n_elec, spin=spin, orb_sym=orb_sym)
mpo = driver.get_qc_mpo(h1e=h1e, g2e=g2e, ecore=ecore, iprint=0)
ket = driver.get_random_mps(tag="KET", bond_dim=250, nroots=1)

bond_dims = [250] * 4 + [500] * 4 + [750] * 4 + [1000] * 4
noises = [1e-4] * 4 + [1e-5] * 12 + [0]
thrds = [1e-8] * 20

energy = driver.dmrg(mpo, ket, n_sweeps=28, bond_dims=bond_dims, noises=noises,
    thrds=thrds, iprint=2, twosite_to_onesite=20)
print('DMRG energy (variational) = %20.15f' % energy)
# Out:
# converged SCF energy = -75.3869023777059
# NCAS = 26 NCASELEC = 8
# Environment initialization | Nsites =    26 | Center =     0
#  INIT-R <-- Site =   23 ..  Bmem =   200 B Rmem =   200 B T = 0.01
#  INIT-R <-- Site =   22 ..  Bmem = 2.55 KB Rmem = 2.55 KB T = 0.00
#  INIT-R <-- Site =   21 ..  Bmem = 22.6 KB Rmem = 22.6 KB T = 0.00
#  INIT-R <-- Site =   20 ..  Bmem =  237 KB Rmem =  237 KB T = 0.03
#  INIT-R <-- Site =   19 ..  Bmem = 3.46 MB Rmem = 1.62 MB T = 0.21
#  INIT-R <-- Site =   18 ..  Bmem = 25.7 MB Rmem = 1.91 MB T = 0.32
#  INIT-R <-- Site =   17 ..  Bmem = 31.7 MB Rmem = 2.39 MB T = 0.55
#  INIT-R <-- Site =   16 ..  Bmem = 40.6 MB Rmem = 3.04 MB T = 0.86
#  INIT-R <-- Site =   15 ..  Bmem = 51.7 MB Rmem = 3.84 MB T = 1.21
#  INIT-R <-- Site =   14 ..  Bmem = 66.2 MB Rmem = 4.84 MB T = 1.77
#  INIT-R <-- Site =   13 ..  Bmem = 83.1 MB Rmem = 6.77 MB T = 1.80
#  INIT-R <-- Site =   12 ..  Bmem =  116 MB Rmem = 8.38 MB T = 4.38
#  INIT-R <-- Site =   11 ..  Bmem =  127 MB Rmem = 10.0 MB T = 4.09
#  INIT-R <-- Site =   10 ..  Bmem =  144 MB Rmem = 9.57 MB T = 10.25
#  INIT-R <-- Site =    9 ..  Bmem =  122 MB Rmem = 9.15 MB T = 2.72
#  INIT-R <-- Site =    8 ..  Bmem =  116 MB Rmem = 7.99 MB T = 2.62
#  INIT-R <-- Site =    7 ..  Bmem =  101 MB Rmem = 7.88 MB T = 2.62
#  INIT-R <-- Site =    6 ..  Bmem = 97.8 MB Rmem = 6.72 MB T = 3.23
#  INIT-R <-- Site =    5 ..  Bmem = 82.3 MB Rmem = 6.12 MB T = 3.73
#  INIT-R <-- Site =    4 ..  Bmem = 73.9 MB Rmem = 5.19 MB T = 2.41
#  INIT-R <-- Site =    3 ..  Bmem = 61.7 MB Rmem = 4.42 MB T = 2.19
#  INIT-R <-- Site =    2 ..  Bmem = 52.0 MB Rmem = 3.42 MB T = 2.07
#  INIT-R <-- Site =    1 ..  Bmem = 32.7 MB Rmem = 2.33 MB T = 1.27
#  INIT-R <-- Site =    0 ..  Bmem = 19.1 MB Rmem = 1.36 MB T = 0.93
# Time init sweep =       49.511 | MaxBmem =  144 MB | MaxRmem = 9.57 MB
#  | Tread = 0.000 | Twrite = 0.398 | Tfpread = 0.000 | Tfpwrite = 0.351 | data = 107 MB | cpsd = 85.9 MB | Tasync = 0.000
#
#
# Sweep =    0 | Direction =  forward | Bond dimension =  250 | Noise =  1.00e-04 | Dav threshold =  1.00e-08
#  --> Site =    0-   1 .. Mmps =    3 Ndav =   6 E =    -74.2848920054 Error = 0.00e+00 FLOPS = 1.09e+06 Tdav = 0.00 T = 0.44
#  --> Site =    1-   2 .. Mmps =   10 Ndav =   6 E =    -74.8270759121 Error = 0.00e+00 FLOPS = 1.18e+07 Tdav = 0.00 T = 1.49
#  --> Site =    2-   3 .. Mmps =   35 Ndav =   8 E =    -75.4399264227 Error = 0.00e+00 FLOPS = 2.87e+07 Tdav = 0.01 T = 1.82
#  --> Site =    3-   4 .. Mmps =  126 Ndav =  13 E =    -75.5128300575 Error = 0.00e+00 FLOPS = 6.82e+07 Tdav = 0.06 T = 1.86
#  --> Site =    4-   5 .. Mmps =  250 Ndav =  14 E =    -75.5518177150 Error = 1.40e-07 FLOPS = 2.09e+08 Tdav = 0.14 T = 2.09
#  --> Site =    5-   6 .. Mmps =  250 Ndav =  11 E =    -75.5891500696 Error = 4.92e-07 FLOPS = 4.79e+08 Tdav = 0.11 T = 2.28
#  --> Site =    6-   7 .. Mmps =  250 Ndav =   9 E =    -75.5958682759 Error = 2.28e-07 FLOPS = 4.37e+08 Tdav = 0.08 T = 2.51
#  --> Site =    7-   8 .. Mmps =  250 Ndav =   8 E =    -75.6089186044 Error = 2.20e-07 FLOPS = 2.12e+08 Tdav = 0.15 T = 3.67
#  --> Site =    8-   9 .. Mmps =  250 Ndav =   7 E =    -75.6161570937 Error = 1.87e-07 FLOPS = 4.00e+08 Tdav = 0.07 T = 2.98
#  --> Site =    9-  10 .. Mmps =  250 Ndav =   7 E =    -75.6260053169 Error = 1.84e-07 FLOPS = 3.22e+08 Tdav = 0.09 T = 2.46
#  --> Site =   10-  11 .. Mmps =  250 Ndav =   7 E =    -75.6343632235 Error = 1.40e-07 FLOPS = 3.62e+08 Tdav = 0.09 T = 2.54
#  --> Site =   11-  12 .. Mmps =  250 Ndav =   7 E =    -75.6474368387 Error = 8.99e-08 FLOPS = 3.74e+08 Tdav = 0.10 T = 10.13
#  --> Site =   12-  13 .. Mmps =  250 Ndav =   7 E =    -75.6594509402 Error = 1.08e-07 FLOPS = 3.61e+08 Tdav = 0.10 T = 4.26
#  --> Site =   13-  14 .. Mmps =  250 Ndav =   6 E =    -75.6733135783 Error = 9.68e-08 FLOPS = 3.54e+08 Tdav = 0.09 T = 2.94
#  --> Site =   14-  15 .. Mmps =  250 Ndav =   5 E =    -75.6796365116 Error = 8.91e-08 FLOPS = 1.91e+08 Tdav = 0.11 T = 2.58
#  --> Site =   15-  16 .. Mmps =  250 Ndav =   5 E =    -75.6823006277 Error = 8.14e-08 FLOPS = 3.11e+08 Tdav = 0.05 T = 1.63
#  --> Site =   16-  17 .. Mmps =  250 Ndav =   6 E =    -75.6919467723 Error = 2.93e-08 FLOPS = 3.34e+08 Tdav = 0.05 T = 0.82
#  --> Site =   17-  18 .. Mmps =  250 Ndav =   5 E =    -75.6941463201 Error = 5.04e-08 FLOPS = 3.38e+08 Tdav = 0.03 T = 0.61
#  --> Site =   18-  19 .. Mmps =  250 Ndav =   4 E =    -75.6948176472 Error = 1.15e-08 FLOPS = 2.80e+08 Tdav = 0.02 T = 0.44
#  --> Site =   19-  20 .. Mmps =  250 Ndav =   5 E =    -75.6983966348 Error = 1.60e-08 FLOPS = 4.35e+08 Tdav = 0.02 T = 0.28
#  --> Site =   20-  21 .. Mmps =  250 Ndav =   4 E =    -75.6988045936 Error = 3.52e-09 FLOPS = 4.16e+08 Tdav = 0.01 T = 0.14
#  --> Site =   21-  22 .. Mmps =  250 Ndav =   1 E =    -75.6988045919 Error = 1.20e-09 FLOPS = 3.08e+08 Tdav = 0.00 T = 0.09
#  --> Site =   22-  23 .. Mmps =  204 Ndav =   1 E =    -75.6988045918 Error = 6.36e-21 FLOPS = 3.66e+08 Tdav = 0.00 T = 0.05
#  --> Site =   23-  24 .. Mmps =   72 Ndav =   1 E =    -75.6988045918 Error = 7.51e-21 FLOPS = 3.83e+08 Tdav = 0.00 T = 0.03
#  --> Site =   24-  25 .. Mmps =   14 Ndav =   1 E =    -75.6988045918 Error = 8.88e-23 FLOPS = 8.37e+07 Tdav = 0.00 T = 0.01
# Time elapsed =     48.314 | E =     -75.6988045936 | DW = 4.92e-07
# Time sweep =       48.314 | 404 MFLOP/SWP
#  | Dmem = 10.1 MB (0%) | Imem = 61.8 MB (93%) | Hmem = 219 MB | Wmem = 11.6 KB | Pmem = 1.12 MB
#  | Tread = 0.364 | Twrite = 0.213 | Tfpread = 0.349 | Tfpwrite = 0.208 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 83.3 MB | cpsd = 66.7 MB
#  | Trot = 0.320 | Tctr = 0.009 | Tint = 0.004 | Tmid = 0.000 | Tdctr = 0.164 | Tdiag = 0.054 | Tinfo = 0.332
#  | Teff = 45.367 | Tprt = 0.296 | Teig = 1.369 | Tblk = 47.254 | Tmve = 0.907 | Tdm = 0.033 | Tsplt = 0.025 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =    1 | Direction = backward | Bond dimension =  250 | Noise =  1.00e-04 | Dav threshold =  1.00e-08
#  <-- Site =   24-  25 .. Mmps =    3 Ndav =   1 E =    -75.6988045918 Error = 0.00e+00 FLOPS = 4.36e+07 Tdav = 0.00 T = 0.01
#  <-- Site =   23-  24 .. Mmps =    9 Ndav =   1 E =    -75.6988045918 Error = 0.00e+00 FLOPS = 3.97e+08 Tdav = 0.00 T = 0.02
#  <-- Site =   22-  23 .. Mmps =   23 Ndav =   1 E =    -75.6988045918 Error = 0.00e+00 FLOPS = 2.97e+08 Tdav = 0.00 T = 0.03
#  <-- Site =   21-  22 .. Mmps =   46 Ndav =   1 E =    -75.6988045918 Error = 0.00e+00 FLOPS = 3.05e+08 Tdav = 0.00 T = 0.06
#  <-- Site =   20-  21 .. Mmps =   84 Ndav =   2 E =    -75.6988045944 Error = 0.00e+00 FLOPS = 3.76e+08 Tdav = 0.01 T = 0.09
#  <-- Site =   19-  20 .. Mmps =  143 Ndav =   2 E =    -75.6988046953 Error = 0.00e+00 FLOPS = 4.09e+08 Tdav = 0.01 T = 0.13
#  <-- Site =   18-  19 .. Mmps =  222 Ndav =   4 E =    -75.6992261762 Error = 0.00e+00 FLOPS = 5.95e+08 Tdav = 0.02 T = 0.21
#  <-- Site =   17-  18 .. Mmps =  250 Ndav =   4 E =    -75.6993353012 Error = 4.83e-09 FLOPS = 9.58e+08 Tdav = 0.03 T = 0.28
#  <-- Site =   16-  17 .. Mmps =  250 Ndav =   4 E =    -75.6993678454 Error = 2.76e-08 FLOPS = 1.07e+09 Tdav = 0.04 T = 0.37
#  <-- Site =   15-  16 .. Mmps =  250 Ndav =   5 E =    -75.6999200129 Error = 4.96e-08 FLOPS = 1.31e+09 Tdav = 0.06 T = 0.47
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-37efcb0b4e9c> in <cell line: 23>()
#      21 thrds = [1e-8] * 20
#      22
# ---> 23 energy = driver.dmrg(mpo, ket, n_sweeps=28, bond_dims=bond_dims, noises=noises,
#      24     thrds=thrds, iprint=2, twosite_to_onesite=20)
#      25 print('DMRG energy (variational) = %20.15f' % energy)
#
# /usr/local/lib/python3.10/dist-packages/pyblock2/driver/core.py in dmrg(self, mpo, ket, n_sweeps, tol, bond_dims, noises, thrds, iprint, dav_type, cutoff, twosite_to_onesite, dav_max_iter, dav_def_max_size, proj_mpss, proj_weights, store_wfn_spectra, spectra_with_multiplicity, lowmem_noise, sweep_start, forward)
#    2903             assert twosite_to_onesite < n_sweeps
#    2904             if sweep_start < twosite_to_onesite:
# -> 2905                 ener = dmrg.solve(twosite_to_onesite, forward, 0, sweep_start)
#    2906                 dmrg.me.dot = 1
#    2907                 for ext_me in dmrg.ext_mes:
#
# KeyboardInterrupt:

# %% [markdown]
# Then we can restart the calculation using the following script. Note that we change ``driver.get_random_mps`` to ``driver.load_mps`` with the same tag, so that data in the scratch folder ``./tmp`` with that tag will loaded. If we want to use the previous sweep schedule, we can keep the sweep schedule unchanged, and when calling ``driver.dmrg``, we use the ``sweep_start`` parameter to set the sweep index of the interrupted sweep (counting from zero), and the ``forward`` parameter to indicate the direction of the first restarting sweep. Then the DMRG will restart from the middle of the interrupted sweep.
#
# For the MPS loaded from the interrupted sweep, ``driver.adjust_mps`` should not be used after ``driver.load_mps``.

# %%
import numpy as np
from pyblock2._pyscf.ao2mo import integrals as itg
from pyblock2.driver.core import DMRGDriver, SymmetryTypes

from pyscf import gto, scf

mol = gto.M(atom='C 0 0 0; C 0 0 1.2425', basis='ccpvdz', symmetry='d2h')
mf = scf.RHF(mol).run(conv_tol=1E-14)
ncas, n_elec, spin, ecore, h1e, g2e, orb_sym = itg.get_rhf_integrals(mf,
    ncore=2, ncas=26, g2e_symm=8)

print("NCAS = %d NCASELEC = %d" % (ncas, n_elec))
driver = DMRGDriver(scratch="./tmp", symm_type=SymmetryTypes.SU2,
                    stack_mem=4 << 30, n_threads=4)
driver.initialize_system(n_sites=ncas, n_elec=n_elec, spin=spin, orb_sym=orb_sym)
mpo = driver.get_qc_mpo(h1e=h1e, g2e=g2e, ecore=ecore, iprint=0)
ket = driver.load_mps(tag="KET", nroots=1)

bond_dims = [250] * 4 + [500] * 4 + [750] * 4 + [1000] * 4
noises = [1e-4] * 4 + [1e-5] * 12 + [0]
thrds = [1e-8] * 20

sweep_start = 1
forward = sweep_start % 2 == 0

energy = driver.dmrg(mpo, ket, n_sweeps=28, bond_dims=bond_dims, noises=noises,
    thrds=thrds, iprint=2, twosite_to_onesite=20, forward=forward, sweep_start=sweep_start)
print('DMRG energy (variational) = %20.15f' % energy)
# Out:
# converged SCF energy = -75.3869023777058
# NCAS = 26 NCASELEC = 8
# Environment initialization | Nsites =    26 | Center =    12
#  INIT-L --> Site =    1 ..  Bmem =   200 B Rmem =   200 B T = 0.00
#  INIT-L --> Site =    2 ..  Bmem = 2.86 KB Rmem = 2.86 KB T = 0.00
#  INIT-L --> Site =    3 ..  Bmem = 26.6 KB Rmem = 26.6 KB T = 0.00
#  INIT-L --> Site =    4 ..  Bmem =  237 KB Rmem =  237 KB T = 0.02
#  INIT-L --> Site =    5 ..  Bmem = 3.46 MB Rmem = 1.38 MB T = 0.07
#  INIT-L --> Site =    6 ..  Bmem = 20.4 MB Rmem = 1.91 MB T = 0.13
#  INIT-L --> Site =    7 ..  Bmem = 27.4 MB Rmem = 2.63 MB T = 0.14
#  INIT-L --> Site =    8 ..  Bmem = 35.1 MB Rmem = 3.56 MB T = 0.16
#  INIT-L --> Site =    9 ..  Bmem = 44.6 MB Rmem = 4.54 MB T = 0.18
#  INIT-L --> Site =   10 ..  Bmem = 54.2 MB Rmem = 5.57 MB T = 0.19
#  INIT-L --> Site =   11 ..  Bmem = 64.3 MB Rmem = 6.78 MB T = 0.21
#  INIT-L --> Site =   12 ..  Bmem = 75.4 MB Rmem = 7.88 MB T = 0.26
#  INIT-R <-- Site =   23 ..  Bmem =   200 B Rmem =   200 B T = 0.01
#  INIT-R <-- Site =   22 ..  Bmem = 2.55 KB Rmem = 2.27 KB T = 0.00
#  INIT-R <-- Site =   21 ..  Bmem = 20.0 KB Rmem = 12.6 KB T = 0.00
#  INIT-R <-- Site =   20 ..  Bmem =  129 KB Rmem = 50.0 KB T = 0.01
#  INIT-R <-- Site =   19 ..  Bmem =  697 KB Rmem =  228 KB T = 0.02
#  INIT-R <-- Site =   18 ..  Bmem = 2.95 MB Rmem =  845 KB T = 0.03
#  INIT-R <-- Site =   17 ..  Bmem = 10.6 MB Rmem = 2.47 MB T = 0.07
#  INIT-R <-- Site =   16 ..  Bmem = 31.9 MB Rmem = 4.12 MB T = 0.11
#  INIT-R <-- Site =   15 ..  Bmem = 48.8 MB Rmem = 4.60 MB T = 0.16
#  INIT-R <-- Site =   14 ..  Bmem = 55.8 MB Rmem = 5.12 MB T = 0.17
#  INIT-R <-- Site =   13 ..  Bmem = 64.1 MB Rmem = 5.60 MB T = 0.23
#  INIT-R <-- Site =   12 ..  Bmem = 72.2 MB Rmem = 6.41 MB T = 0.36
# Time init sweep =        2.657 | MaxBmem = 75.4 MB | MaxRmem = 7.88 MB
#  | Tread = 0.000 | Twrite = 0.189 | Tfpread = 0.000 | Tfpwrite = 0.160 | data = 63.9 MB | cpsd = 53.1 MB | Tasync = 0.000
#
#
# Sweep =    1 | Direction = backward | Bond dimension =  250 | Noise =  1.00e-04 | Dav threshold =  1.00e-08
#  <-- Site =   12-  13 .. Mmps =  250 Ndav =   6 E =    -75.7019455569 Error = 2.43e-07 FLOPS = 1.52e+09 Tdav = 0.14 T = 1.51
#  <-- Site =   11-  12 .. Mmps =  250 Ndav =   6 E =    -75.7033367067 Error = 2.75e-07 FLOPS = 1.56e+09 Tdav = 0.15 T = 1.39
#  <-- Site =   10-  11 .. Mmps =  250 Ndav =   7 E =    -75.7054373205 Error = 5.29e-07 FLOPS = 1.74e+09 Tdav = 0.15 T = 0.65
#  <-- Site =    9-  10 .. Mmps =  250 Ndav =   7 E =    -75.7087798252 Error = 5.56e-07 FLOPS = 1.91e+09 Tdav = 0.13 T = 0.57
#  <-- Site =    8-   9 .. Mmps =  250 Ndav =   7 E =    -75.7103058282 Error = 7.69e-07 FLOPS = 2.12e+09 Tdav = 0.12 T = 0.51
#  <-- Site =    7-   8 .. Mmps =  250 Ndav =   7 E =    -75.7119354371 Error = 1.88e-06 FLOPS = 2.26e+09 Tdav = 0.13 T = 0.51
#  <-- Site =    6-   7 .. Mmps =  250 Ndav =   9 E =    -75.7148564117 Error = 6.02e-06 FLOPS = 2.31e+09 Tdav = 0.16 T = 0.50
#  <-- Site =    5-   6 .. Mmps =  250 Ndav =  11 E =    -75.7194018891 Error = 3.92e-05 FLOPS = 1.25e+09 Tdav = 0.39 T = 0.82
#  <-- Site =    4-   5 .. Mmps =  250 Ndav =  14 E =    -75.7234052111 Error = 4.32e-05 FLOPS = 7.05e+08 Tdav = 0.42 T = 0.81
#  <-- Site =    3-   4 .. Mmps =  250 Ndav =   5 E =    -75.7232592109 Error = 2.20e-06 FLOPS = 2.64e+08 Tdav = 0.07 T = 0.29
#  <-- Site =    2-   3 .. Mmps =  250 Ndav =   1 E =    -75.7232592101 Error = 3.64e-08 FLOPS = 1.10e+08 Tdav = 0.01 T = 0.15
#  <-- Site =    1-   2 .. Mmps =  112 Ndav =   1 E =    -75.7232592101 Error = 1.33e-20 FLOPS = 1.39e+08 Tdav = 0.00 T = 0.09
#  <-- Site =    0-   1 .. Mmps =   18 Ndav =   1 E =    -75.7232592101 Error = 1.47e-21 FLOPS = 1.70e+07 Tdav = 0.00 T = 0.02
# Time elapsed =      7.886 | E =     -75.7234052111 | DE = -7.57e+01 | DW = 4.32e-05
# Time sweep =        7.886 | 2.45 GFLOP/SWP
#  | Dmem = 7.99 MB (1%) | Imem = 2.38 MB (96%) | Hmem = 150 MB | Wmem = 59.4 KB | Pmem = 4.98 MB
#  | Tread = 0.069 | Twrite = 0.111 | Tfpread = 0.068 | Tfpwrite = 0.108 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 41.0 MB | cpsd = 33.0 MB
#  | Trot = 0.230 | Tctr = 0.005 | Tint = 0.006 | Tmid = 0.000 | Tdctr = 0.007 | Tdiag = 0.051 | Tinfo = 0.136
#  | Teff = 4.712 | Tprt = 0.661 | Teig = 1.844 | Tblk = 7.307 | Tmve = 0.496 | Tdm = 0.038 | Tsplt = 0.025 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =    2 | Direction =  forward | Bond dimension =  250 | Noise =  1.00e-04 | Dav threshold =  1.00e-08
#  --> Site =    0-   1 .. Mmps =    3 Ndav =   1 E =    -75.7232592101 Error = 0.00e+00 FLOPS = 1.53e+07 Tdav = 0.00 T = 0.01
#  --> Site =    1-   2 .. Mmps =   10 Ndav =   1 E =    -75.7232592101 Error = 0.00e+00 FLOPS = 1.32e+08 Tdav = 0.00 T = 0.06
#  --> Site =    2-   3 .. Mmps =   35 Ndav =   1 E =    -75.7232592101 Error = 0.00e+00 FLOPS = 1.09e+08 Tdav = 0.01 T = 0.10
#  --> Site =    3-   4 .. Mmps =  126 Ndav =   2 E =    -75.7232592142 Error = 0.00e+00 FLOPS = 2.49e+08 Tdav = 0.03 T = 0.23
#  --> Site =    4-   5 .. Mmps =  250 Ndav =   6 E =    -75.7234052136 Error = 4.13e-05 FLOPS = 7.38e+08 Tdav = 0.17 T = 0.53
#  --> Site =    5-   6 .. Mmps =  250 Ndav =   7 E =    -75.7237452930 Error = 6.80e-05 FLOPS = 1.77e+09 Tdav = 0.21 T = 0.72
#  --> Site =    6-   7 .. Mmps =  250 Ndav =   6 E =    -75.7237136502 Error = 2.41e-05 FLOPS = 2.80e+09 Tdav = 0.13 T = 0.50
#  --> Site =    7-   8 .. Mmps =  250 Ndav =   6 E =    -75.7239111826 Error = 1.17e-05 FLOPS = 3.07e+09 Tdav = 0.13 T = 0.54
#  --> Site =    8-   9 .. Mmps =  250 Ndav =   5 E =    -75.7241648868 Error = 8.29e-06 FLOPS = 2.44e+09 Tdav = 0.15 T = 0.59
#  --> Site =    9-  10 .. Mmps =  250 Ndav =   5 E =    -75.7243750111 Error = 7.52e-06 FLOPS = 3.08e+09 Tdav = 0.13 T = 0.59
#  --> Site =   10-  11 .. Mmps =  250 Ndav =   5 E =    -75.7245369229 Error = 4.19e-06 FLOPS = 2.91e+09 Tdav = 0.14 T = 0.65
#  --> Site =   11-  12 .. Mmps =  250 Ndav =   5 E =    -75.7246985832 Error = 2.16e-06 FLOPS = 2.88e+09 Tdav = 0.15 T = 1.39
#  --> Site =   12-  13 .. Mmps =  250 Ndav =   5 E =    -75.7248097165 Error = 2.05e-06 FLOPS = 2.57e+09 Tdav = 0.15 T = 1.60
#  --> Site =   13-  14 .. Mmps =  250 Ndav =   4 E =    -75.7248481163 Error = 1.27e-06 FLOPS = 2.51e+09 Tdav = 0.10 T = 0.98
#  --> Site =   14-  15 .. Mmps =  250 Ndav =   4 E =    -75.7248926895 Error = 9.45e-07 FLOPS = 2.21e+09 Tdav = 0.09 T = 0.74
#  --> Site =   15-  16 .. Mmps =  250 Ndav =   4 E =    -75.7249114972 Error = 8.19e-07 FLOPS = 1.99e+09 Tdav = 0.07 T = 0.51
#  --> Site =   16-  17 .. Mmps =  250 Ndav =   3 E =    -75.7249191345 Error = 2.75e-07 FLOPS = 1.69e+09 Tdav = 0.04 T = 0.41
#  --> Site =   17-  18 .. Mmps =  250 Ndav =   3 E =    -75.7249226753 Error = 2.33e-07 FLOPS = 1.41e+09 Tdav = 0.03 T = 0.35
#  --> Site =   18-  19 .. Mmps =  250 Ndav =   3 E =    -75.7249233359 Error = 8.79e-08 FLOPS = 8.67e+08 Tdav = 0.02 T = 0.24
#  --> Site =   19-  20 .. Mmps =  250 Ndav =   3 E =    -75.7249237309 Error = 4.94e-08 FLOPS = 5.87e+08 Tdav = 0.02 T = 0.18
#  --> Site =   20-  21 .. Mmps =  250 Ndav =   2 E =    -75.7249238259 Error = 2.23e-08 FLOPS = 3.71e+08 Tdav = 0.01 T = 0.13
#  --> Site =   21-  22 .. Mmps =  250 Ndav =   2 E =    -75.7249238396 Error = 4.19e-09 FLOPS = 2.71e+08 Tdav = 0.01 T = 0.10
#  --> Site =   22-  23 .. Mmps =  229 Ndav =   2 E =    -75.7249238890 Error = 1.19e-21 FLOPS = 1.92e+08 Tdav = 0.00 T = 0.06
#  --> Site =   23-  24 .. Mmps =   82 Ndav =   2 E =    -75.7249238917 Error = 7.54e-21 FLOPS = 2.05e+08 Tdav = 0.00 T = 0.03
#  --> Site =   24-  25 .. Mmps =   13 Ndav =   1 E =    -75.7249238917 Error = 5.36e-21 FLOPS = 1.80e+07 Tdav = 0.00 T = 0.01
# Time elapsed =     19.296 | E =     -75.7249238917 | DE = -1.52e-03 | DW = 6.80e-05
# Time sweep =       11.410 | 3.76 GFLOP/SWP
#  | Dmem = 6.96 MB (1%) | Imem = 2.38 MB (96%) | Hmem = 144 MB | Wmem = 69.4 KB | Pmem = 5.39 MB
#  | Tread = 0.227 | Twrite = 0.166 | Tfpread = 0.222 | Tfpwrite = 0.158 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 67.9 MB | cpsd = 54.6 MB
#  | Trot = 0.321 | Tctr = 0.013 | Tint = 0.009 | Tmid = 0.000 | Tdctr = 0.123 | Tdiag = 0.085 | Tinfo = 0.342
#  | Teff = 7.574 | Tprt = 0.867 | Teig = 1.811 | Tblk = 10.397 | Tmve = 0.865 | Tdm = 0.062 | Tsplt = 0.032 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =    3 | Direction = backward | Bond dimension =  250 | Noise =  1.00e-04 | Dav threshold =  1.00e-08
#  <-- Site =   24-  25 .. Mmps =    3 Ndav =   1 E =    -75.7249238917 Error = 0.00e+00 FLOPS = 1.74e+07 Tdav = 0.00 T = 0.01
#  <-- Site =   23-  24 .. Mmps =   10 Ndav =   1 E =    -75.7249238917 Error = 0.00e+00 FLOPS = 1.66e+08 Tdav = 0.00 T = 0.02
#  <-- Site =   22-  23 .. Mmps =   28 Ndav =   1 E =    -75.7249238917 Error = 0.00e+00 FLOPS = 1.57e+08 Tdav = 0.00 T = 0.04
#  <-- Site =   21-  22 .. Mmps =   57 Ndav =   2 E =    -75.7249238933 Error = 0.00e+00 FLOPS = 2.69e+08 Tdav = 0.01 T = 0.09
#  <-- Site =   20-  21 .. Mmps =  114 Ndav =   2 E =    -75.7249239063 Error = 0.00e+00 FLOPS = 2.03e+08 Tdav = 0.02 T = 0.18
#  <-- Site =   19-  20 .. Mmps =  208 Ndav =   2 E =    -75.7249239233 Error = 0.00e+00 FLOPS = 2.99e+08 Tdav = 0.02 T = 0.28
#  <-- Site =   18-  19 .. Mmps =  250 Ndav =   2 E =    -75.7249239605 Error = 5.16e-10 FLOPS = 4.58e+08 Tdav = 0.03 T = 0.41
#  <-- Site =   17-  18 .. Mmps =  250 Ndav =   2 E =    -75.7249241027 Error = 1.81e-08 FLOPS = 7.00e+08 Tdav = 0.04 T = 0.58
#  <-- Site =   16-  17 .. Mmps =  250 Ndav =   2 E =    -75.7249242715 Error = 6.36e-08 FLOPS = 8.59e+08 Tdav = 0.06 T = 0.68
#  <-- Site =   15-  16 .. Mmps =  250 Ndav =   3 E =    -75.7249251140 Error = 9.84e-08 FLOPS = 1.18e+09 Tdav = 0.09 T = 0.84
#  <-- Site =   14-  15 .. Mmps =  250 Ndav =   3 E =    -75.7249261153 Error = 1.82e-07 FLOPS = 2.19e+09 Tdav = 0.07 T = 0.97
#  <-- Site =   13-  14 .. Mmps =  250 Ndav =   3 E =    -75.7249287653 Error = 3.00e-07 FLOPS = 2.50e+09 Tdav = 0.08 T = 0.97
#  <-- Site =   12-  13 .. Mmps =  250 Ndav =   3 E =    -75.7249339151 Error = 5.92e-07 FLOPS = 2.57e+09 Tdav = 0.09 T = 1.57
#  <-- Site =   11-  12 .. Mmps =  250 Ndav =   3 E =    -75.7249379223 Error = 6.35e-07 FLOPS = 2.84e+09 Tdav = 0.09 T = 1.39
#  <-- Site =   10-  11 .. Mmps =  250 Ndav =   4 E =    -75.7249575289 Error = 1.81e-06 FLOPS = 2.90e+09 Tdav = 0.11 T = 0.65
#  <-- Site =    9-  10 .. Mmps =  250 Ndav =   4 E =    -75.7249945619 Error = 4.71e-06 FLOPS = 2.78e+09 Tdav = 0.11 T = 0.59
#  <-- Site =    8-   9 .. Mmps =  250 Ndav =   4 E =    -75.7250110719 Error = 4.87e-06 FLOPS = 2.79e+09 Tdav = 0.10 T = 0.56
#  <-- Site =    7-   8 .. Mmps =  250 Ndav =   4 E =    -75.7250495206 Error = 7.48e-06 FLOPS = 2.76e+09 Tdav = 0.09 T = 0.51
#  <-- Site =    6-   7 .. Mmps =  250 Ndav =   5 E =    -75.7251768782 Error = 1.83e-05 FLOPS = 2.76e+09 Tdav = 0.11 T = 0.48
#  <-- Site =    5-   6 .. Mmps =  250 Ndav =   6 E =    -75.7254307257 Error = 6.87e-05 FLOPS = 2.59e+09 Tdav = 0.13 T = 0.45
#  <-- Site =    4-   5 .. Mmps =  250 Ndav =   7 E =    -75.7253660998 Error = 4.81e-05 FLOPS = 1.36e+09 Tdav = 0.11 T = 0.35
#  <-- Site =    3-   4 .. Mmps =  250 Ndav =   5 E =    -75.7251980323 Error = 2.26e-06 FLOPS = 5.11e+08 Tdav = 0.04 T = 0.17
#  <-- Site =    2-   3 .. Mmps =  250 Ndav =   1 E =    -75.7251980316 Error = 3.74e-08 FLOPS = 1.98e+08 Tdav = 0.00 T = 0.09
#  <-- Site =    1-   2 .. Mmps =  115 Ndav =   1 E =    -75.7251980316 Error = 1.97e-20 FLOPS = 2.45e+08 Tdav = 0.00 T = 0.05
#  <-- Site =    0-   1 .. Mmps =   16 Ndav =   1 E =    -75.7251980316 Error = 1.43e-21 FLOPS = 3.13e+07 Tdav = 0.00 T = 0.02
# Time elapsed =     31.390 | E =     -75.7254307257 | DE = -5.07e-04 | DW = 6.87e-05
# Time sweep =       12.094 | 2.75 GFLOP/SWP
#  | Dmem = 6.91 MB (1%) | Imem = 2.40 MB (96%) | Hmem = 143 MB | Wmem = 69.3 KB | Pmem = 5.38 MB
#  | Tread = 0.139 | Twrite = 0.211 | Tfpread = 0.134 | Tfpwrite = 0.206 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 69.9 MB | cpsd = 57.1 MB
#  | Trot = 0.383 | Tctr = 0.016 | Tint = 0.015 | Tmid = 0.000 | Tdctr = 0.014 | Tdiag = 0.088 | Tinfo = 0.210
#  | Teff = 8.373 | Tprt = 1.167 | Teig = 1.382 | Tblk = 11.077 | Tmve = 0.855 | Tdm = 0.060 | Tsplt = 0.036 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =    4 | Direction =  forward | Bond dimension =  500 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  --> Site =    0-   1 .. Mmps =    3 Ndav =   1 E =    -75.7251980316 Error = 0.00e+00 FLOPS = 1.57e+07 Tdav = 0.00 T = 0.01
#  --> Site =    1-   2 .. Mmps =   10 Ndav =   1 E =    -75.7251980316 Error = 0.00e+00 FLOPS = 1.64e+08 Tdav = 0.00 T = 0.04
#  --> Site =    2-   3 .. Mmps =   35 Ndav =   1 E =    -75.7251980316 Error = 0.00e+00 FLOPS = 1.91e+08 Tdav = 0.00 T = 0.06
#  --> Site =    3-   4 .. Mmps =  126 Ndav =   1 E =    -75.7251980316 Error = 0.00e+00 FLOPS = 3.54e+08 Tdav = 0.01 T = 0.12
#  --> Site =    4-   5 .. Mmps =  418 Ndav =   7 E =    -75.7253661027 Error = 0.00e+00 FLOPS = 1.13e+09 Tdav = 0.13 T = 0.33
#  --> Site =    5-   6 .. Mmps =  500 Ndav =   9 E =    -75.7257735088 Error = 3.97e-06 FLOPS = 3.86e+09 Tdav = 0.29 T = 0.76
#  --> Site =    6-   7 .. Mmps =  500 Ndav =   6 E =    -75.7259667099 Error = 1.12e-06 FLOPS = 2.82e+09 Tdav = 0.45 T = 1.36
#  --> Site =    7-   8 .. Mmps =  500 Ndav =   5 E =    -75.7262124157 Error = 5.25e-07 FLOPS = 2.77e+09 Tdav = 0.43 T = 1.82
#  --> Site =    8-   9 .. Mmps =  500 Ndav =   5 E =    -75.7264691420 Error = 5.15e-07 FLOPS = 4.90e+09 Tdav = 0.29 T = 1.48
#  --> Site =    9-  10 .. Mmps =  500 Ndav =   5 E =    -75.7266957987 Error = 4.25e-07 FLOPS = 5.13e+09 Tdav = 0.32 T = 1.27
#  --> Site =   10-  11 .. Mmps =  500 Ndav =   5 E =    -75.7269168383 Error = 2.93e-07 FLOPS = 5.27e+09 Tdav = 0.35 T = 1.36
#  --> Site =   11-  12 .. Mmps =  500 Ndav =   5 E =    -75.7270750756 Error = 2.07e-07 FLOPS = 5.19e+09 Tdav = 0.39 T = 2.26
#  --> Site =   12-  13 .. Mmps =  500 Ndav =   4 E =    -75.7271854729 Error = 1.49e-07 FLOPS = 4.74e+09 Tdav = 0.33 T = 3.38
#  --> Site =   13-  14 .. Mmps =  500 Ndav =   4 E =    -75.7272582167 Error = 8.86e-08 FLOPS = 2.58e+09 Tdav = 0.53 T = 2.51
#  --> Site =   14-  15 .. Mmps =  500 Ndav =   4 E =    -75.7273066233 Error = 6.50e-08 FLOPS = 2.61e+09 Tdav = 0.40 T = 2.62
#  --> Site =   15-  16 .. Mmps =  500 Ndav =   4 E =    -75.7273314216 Error = 5.69e-08 FLOPS = 3.87e+09 Tdav = 0.20 T = 1.05
#  --> Site =   16-  17 .. Mmps =  500 Ndav =   4 E =    -75.7273471908 Error = 2.27e-08 FLOPS = 3.28e+09 Tdav = 0.18 T = 0.90
#  --> Site =   17-  18 .. Mmps =  500 Ndav =   3 E =    -75.7273535904 Error = 1.15e-08 FLOPS = 3.43e+09 Tdav = 0.09 T = 0.70
#  --> Site =   18-  19 .. Mmps =  500 Ndav =   3 E =    -75.7273551591 Error = 4.46e-09 FLOPS = 2.33e+09 Tdav = 0.06 T = 0.56
#  --> Site =   19-  20 .. Mmps =  500 Ndav =   2 E =    -75.7273554387 Error = 2.43e-09 FLOPS = 1.46e+09 Tdav = 0.03 T = 0.37
#  --> Site =   20-  21 .. Mmps =  500 Ndav =   2 E =    -75.7273554986 Error = 6.12e-10 FLOPS = 9.59e+08 Tdav = 0.02 T = 0.26
#  --> Site =   21-  22 .. Mmps =  500 Ndav =   2 E =    -75.7273557488 Error = 1.40e-10 FLOPS = 5.65e+08 Tdav = 0.01 T = 0.22
#  --> Site =   22-  23 .. Mmps =  405 Ndav =   2 E =    -75.7273558056 Error = 1.56e-20 FLOPS = 5.31e+08 Tdav = 0.01 T = 0.18
#  --> Site =   23-  24 .. Mmps =   99 Ndav =   1 E =    -75.7273558056 Error = 1.27e-20 FLOPS = 4.35e+08 Tdav = 0.00 T = 0.07
#  --> Site =   24-  25 .. Mmps =   13 Ndav =   1 E =    -75.7273558056 Error = 1.32e-20 FLOPS = 2.44e+07 Tdav = 0.00 T = 0.01
# Time elapsed =     55.273 | E =     -75.7273558056 | DE = -1.93e-03 | DW = 3.97e-06
# Time sweep =       23.883 | 15.4 GFLOP/SWP
#  | Dmem = 23.6 MB (1%) | Imem = 3.02 MB (96%) | Hmem = 347 MB | Wmem = 146 KB | Pmem = 11.2 MB
#  | Tread = 0.549 | Twrite = 0.684 | Tfpread = 0.543 | Tfpwrite = 0.679 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 250 MB | cpsd = 201 MB
#  | Trot = 0.947 | Tctr = 0.019 | Tint = 0.009 | Tmid = 0.000 | Tdctr = 0.437 | Tdiag = 0.128 | Tinfo = 0.478
#  | Teff = 14.022 | Tprt = 2.702 | Teig = 4.515 | Tblk = 21.566 | Tmve = 2.156 | Tdm = 0.151 | Tsplt = 0.087 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =    5 | Direction = backward | Bond dimension =  500 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  <-- Site =   24-  25 .. Mmps =    3 Ndav =   1 E =    -75.7273558056 Error = 0.00e+00 FLOPS = 2.30e+07 Tdav = 0.00 T = 0.01
#  <-- Site =   23-  24 .. Mmps =   10 Ndav =   1 E =    -75.7273558056 Error = 0.00e+00 FLOPS = 4.59e+08 Tdav = 0.00 T = 0.04
#  <-- Site =   22-  23 .. Mmps =   31 Ndav =   1 E =    -75.7273558056 Error = 0.00e+00 FLOPS = 4.62e+08 Tdav = 0.00 T = 0.08
#  <-- Site =   21-  22 .. Mmps =   80 Ndav =   1 E =    -75.7273558056 Error = 0.00e+00 FLOPS = 5.65e+08 Tdav = 0.01 T = 0.15
#  <-- Site =   20-  21 .. Mmps =  173 Ndav =   2 E =    -75.7273558074 Error = 0.00e+00 FLOPS = 9.56e+08 Tdav = 0.02 T = 0.23
#  <-- Site =   19-  20 .. Mmps =  333 Ndav =   2 E =    -75.7273558176 Error = 0.00e+00 FLOPS = 9.49e+08 Tdav = 0.04 T = 0.45
#  <-- Site =   18-  19 .. Mmps =  500 Ndav =   2 E =    -75.7273558269 Error = 3.70e-11 FLOPS = 1.88e+09 Tdav = 0.05 T = 0.66
#  <-- Site =   17-  18 .. Mmps =  500 Ndav =   3 E =    -75.7273566664 Error = 5.75e-10 FLOPS = 3.45e+09 Tdav = 0.10 T = 1.11
#  <-- Site =   16-  17 .. Mmps =  500 Ndav =   3 E =    -75.7273571781 Error = 3.00e-09 FLOPS = 4.06e+09 Tdav = 0.15 T = 1.15
#  <-- Site =   15-  16 .. Mmps =  500 Ndav =   3 E =    -75.7273587280 Error = 8.12e-09 FLOPS = 2.75e+09 Tdav = 0.37 T = 2.13
#  <-- Site =   14-  15 .. Mmps =  500 Ndav =   3 E =    -75.7273598091 Error = 1.82e-08 FLOPS = 2.68e+09 Tdav = 0.53 T = 4.01
#  <-- Site =   13-  14 .. Mmps =  500 Ndav =   3 E =    -75.7273614000 Error = 2.82e-08 FLOPS = 5.68e+09 Tdav = 0.32 T = 3.38
#  <-- Site =   12-  13 .. Mmps =  500 Ndav =   3 E =    -75.7273659236 Error = 4.68e-08 FLOPS = 5.84e+09 Tdav = 0.34 T = 4.25
#  <-- Site =   11-  12 .. Mmps =  500 Ndav =   4 E =    -75.7273764077 Error = 8.96e-08 FLOPS = 6.26e+09 Tdav = 0.46 T = 4.03
#  <-- Site =   10-  11 .. Mmps =  500 Ndav =   4 E =    -75.7273979421 Error = 3.39e-07 FLOPS = 3.63e+09 Tdav = 0.74 T = 3.27
#  <-- Site =    9-  10 .. Mmps =  500 Ndav =   4 E =    -75.7274389878 Error = 1.01e-06 FLOPS = 6.92e+09 Tdav = 0.36 T = 1.80
#  <-- Site =    8-   9 .. Mmps =  500 Ndav =   4 E =    -75.7274920505 Error = 1.60e-06 FLOPS = 6.86e+09 Tdav = 0.33 T = 1.55
#  <-- Site =    7-   8 .. Mmps =  500 Ndav =   5 E =    -75.7275654540 Error = 2.24e-06 FLOPS = 6.66e+09 Tdav = 0.37 T = 1.45
#  <-- Site =    6-   7 .. Mmps =  500 Ndav =   6 E =    -75.7276988453 Error = 4.25e-06 FLOPS = 6.24e+09 Tdav = 0.45 T = 1.41
#  <-- Site =    5-   6 .. Mmps =  500 Ndav =   9 E =    -75.7278860763 Error = 1.58e-05 FLOPS = 5.60e+09 Tdav = 0.50 T = 1.23
#  <-- Site =    4-   5 .. Mmps =  500 Ndav =   5 E =    -75.7278120707 Error = 1.86e-07 FLOPS = 2.60e+09 Tdav = 0.12 T = 0.52
#  <-- Site =    3-   4 .. Mmps =  500 Ndav =   1 E =    -75.7278120705 Error = 8.21e-08 FLOPS = 6.21e+08 Tdav = 0.02 T = 0.28
#  <-- Site =    2-   3 .. Mmps =  500 Ndav =   1 E =    -75.7278120705 Error = 5.04e-10 FLOPS = 6.49e+08 Tdav = 0.00 T = 0.15
#  <-- Site =    1-   2 .. Mmps =  114 Ndav =   1 E =    -75.7278120705 Error = 1.82e-20 FLOPS = 6.14e+08 Tdav = 0.00 T = 0.10
#  <-- Site =    0-   1 .. Mmps =   17 Ndav =   1 E =    -75.7278120705 Error = 1.40e-22 FLOPS = 3.20e+07 Tdav = 0.00 T = 0.02
# Time elapsed =     88.911 | E =     -75.7278860763 | DE = -5.30e-04 | DW = 1.58e-05
# Time sweep =       33.638 | 24.4 GFLOP/SWP
#  | Dmem = 26.7 MB (1%) | Imem = 3.23 MB (96%) | Hmem = 571 MB | Wmem = 243 KB | Pmem = 20.5 MB
#  | Tread = 0.476 | Twrite = 0.808 | Tfpread = 0.474 | Tfpwrite = 0.803 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 265 MB | cpsd = 216 MB
#  | Trot = 1.120 | Tctr = 0.014 | Tint = 0.023 | Tmid = 0.000 | Tdctr = 0.015 | Tdiag = 0.151 | Tinfo = 0.277
#  | Teff = 20.032 | Tprt = 5.251 | Teig = 5.312 | Tblk = 31.156 | Tmve = 2.297 | Tdm = 0.254 | Tsplt = 0.115 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =    6 | Direction =  forward | Bond dimension =  500 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  --> Site =    0-   1 .. Mmps =    3 Ndav =   1 E =    -75.7278120705 Error = 0.00e+00 FLOPS = 3.19e+07 Tdav = 0.00 T = 0.01
#  --> Site =    1-   2 .. Mmps =   10 Ndav =   1 E =    -75.7278120705 Error = 0.00e+00 FLOPS = 6.34e+08 Tdav = 0.00 T = 0.07
#  --> Site =    2-   3 .. Mmps =   35 Ndav =   1 E =    -75.7278120705 Error = 0.00e+00 FLOPS = 4.70e+08 Tdav = 0.01 T = 0.10
#  --> Site =    3-   4 .. Mmps =  126 Ndav =   1 E =    -75.7278120705 Error = 0.00e+00 FLOPS = 9.50e+08 Tdav = 0.01 T = 0.22
#  --> Site =    4-   5 .. Mmps =  421 Ndav =   1 E =    -75.7278120705 Error = 0.00e+00 FLOPS = 2.34e+09 Tdav = 0.03 T = 0.36
#  --> Site =    5-   6 .. Mmps =  500 Ndav =   6 E =    -75.7278862359 Error = 1.67e-05 FLOPS = 5.65e+09 Tdav = 0.33 T = 1.12
#  --> Site =    6-   7 .. Mmps =  500 Ndav =   5 E =    -75.7278386169 Error = 5.60e-06 FLOPS = 3.81e+09 Tdav = 0.61 T = 2.23
#  --> Site =    7-   8 .. Mmps =  500 Ndav =   4 E =    -75.7278422938 Error = 3.07e-06 FLOPS = 6.79e+09 Tdav = 0.27 T = 1.85
#  --> Site =    8-   9 .. Mmps =  500 Ndav =   4 E =    -75.7278572701 Error = 2.34e-06 FLOPS = 6.56e+09 Tdav = 0.34 T = 1.54
#  --> Site =    9-  10 .. Mmps =  500 Ndav =   4 E =    -75.7278659295 Error = 2.09e-06 FLOPS = 6.69e+09 Tdav = 0.39 T = 1.75
#  --> Site =   10-  11 .. Mmps =  500 Ndav =   4 E =    -75.7278694945 Error = 9.57e-07 FLOPS = 6.95e+09 Tdav = 0.41 T = 1.97
#  --> Site =   11-  12 .. Mmps =  500 Ndav =   4 E =    -75.7278751587 Error = 5.13e-07 FLOPS = 6.69e+09 Tdav = 0.49 T = 3.95
#  --> Site =   12-  13 .. Mmps =  500 Ndav =   3 E =    -75.7278789223 Error = 3.46e-07 FLOPS = 6.40e+09 Tdav = 0.37 T = 6.04
#  --> Site =   13-  14 .. Mmps =  500 Ndav =   3 E =    -75.7278801996 Error = 1.78e-07 FLOPS = 6.17e+09 Tdav = 0.34 T = 2.84
#  --> Site =   14-  15 .. Mmps =  500 Ndav =   3 E =    -75.7278808680 Error = 1.32e-07 FLOPS = 5.88e+09 Tdav = 0.28 T = 2.13
#  --> Site =   15-  16 .. Mmps =  500 Ndav =   3 E =    -75.7278813070 Error = 1.08e-07 FLOPS = 5.85e+09 Tdav = 0.21 T = 1.53
#  --> Site =   16-  17 .. Mmps =  500 Ndav =   2 E =    -75.7278812386 Error = 3.26e-08 FLOPS = 4.82e+09 Tdav = 0.10 T = 1.18
#  --> Site =   17-  18 .. Mmps =  500 Ndav =   2 E =    -75.7278812620 Error = 1.51e-08 FLOPS = 1.98e+09 Tdav = 0.14 T = 1.22
#  --> Site =   18-  19 .. Mmps =  500 Ndav =   2 E =    -75.7278812812 Error = 6.11e-09 FLOPS = 1.35e+09 Tdav = 0.08 T = 1.09
#  --> Site =   19-  20 .. Mmps =  500 Ndav =   2 E =    -75.7278812800 Error = 3.27e-09 FLOPS = 8.75e+08 Tdav = 0.05 T = 0.69
#  --> Site =   20-  21 .. Mmps =  500 Ndav =   1 E =    -75.7278812794 Error = 7.95e-10 FLOPS = 4.91e+08 Tdav = 0.02 T = 0.46
#  --> Site =   21-  22 .. Mmps =  500 Ndav =   1 E =    -75.7278812791 Error = 1.62e-10 FLOPS = 4.03e+08 Tdav = 0.01 T = 0.31
#  --> Site =   22-  23 .. Mmps =  415 Ndav =   1 E =    -75.7278812791 Error = 1.67e-20 FLOPS = 2.27e+08 Tdav = 0.01 T = 0.21
#  --> Site =   23-  24 .. Mmps =   98 Ndav =   1 E =    -75.7278812791 Error = 1.23e-20 FLOPS = 2.41e+08 Tdav = 0.00 T = 0.12
#  --> Site =   24-  25 .. Mmps =   14 Ndav =   1 E =    -75.7278812791 Error = 1.78e-21 FLOPS = 1.29e+07 Tdav = 0.00 T = 0.02
# Time elapsed =    122.108 | E =     -75.7278862359 | DE = -1.60e-07 | DW = 1.67e-05
# Time sweep =       33.197 | 23.6 GFLOP/SWP
#  | Dmem = 26.7 MB (1%) | Imem = 3.30 MB (96%) | Hmem = 578 MB | Wmem = 241 KB | Pmem = 20.4 MB
#  | Tread = 0.960 | Twrite = 0.669 | Tfpread = 0.955 | Tfpwrite = 0.663 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 256 MB | cpsd = 205 MB
#  | Trot = 0.953 | Tctr = 0.026 | Tint = 0.010 | Tmid = 0.000 | Tdctr = 0.516 | Tdiag = 0.141 | Tinfo = 0.567
#  | Teff = 21.205 | Tprt = 4.525 | Teig = 4.505 | Tblk = 30.746 | Tmve = 2.273 | Tdm = 0.255 | Tsplt = 0.104 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =    7 | Direction = backward | Bond dimension =  500 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  <-- Site =   24-  25 .. Mmps =    3 Ndav =   1 E =    -75.7278812791 Error = 0.00e+00 FLOPS = 1.24e+07 Tdav = 0.00 T = 0.01
#  <-- Site =   23-  24 .. Mmps =   10 Ndav =   1 E =    -75.7278812791 Error = 0.00e+00 FLOPS = 4.66e+08 Tdav = 0.00 T = 0.05
#  <-- Site =   22-  23 .. Mmps =   31 Ndav =   1 E =    -75.7278812791 Error = 0.00e+00 FLOPS = 4.57e+08 Tdav = 0.00 T = 0.08
#  <-- Site =   21-  22 .. Mmps =   80 Ndav =   1 E =    -75.7278812791 Error = 0.00e+00 FLOPS = 4.82e+08 Tdav = 0.01 T = 0.16
#  <-- Site =   20-  21 .. Mmps =  174 Ndav =   1 E =    -75.7278812791 Error = 0.00e+00 FLOPS = 8.99e+08 Tdav = 0.01 T = 0.20
#  <-- Site =   19-  20 .. Mmps =  335 Ndav =   1 E =    -75.7278812791 Error = 0.00e+00 FLOPS = 1.48e+09 Tdav = 0.01 T = 0.33
#  <-- Site =   18-  19 .. Mmps =  500 Ndav =   2 E =    -75.7278812827 Error = 4.78e-11 FLOPS = 2.55e+09 Tdav = 0.04 T = 0.55
#  <-- Site =   17-  18 .. Mmps =  500 Ndav =   2 E =    -75.7278812948 Error = 6.98e-10 FLOPS = 3.83e+09 Tdav = 0.07 T = 0.87
#  <-- Site =   16-  17 .. Mmps =  500 Ndav =   2 E =    -75.7278813506 Error = 3.45e-09 FLOPS = 4.74e+09 Tdav = 0.10 T = 1.13
#  <-- Site =   15-  16 .. Mmps =  500 Ndav =   3 E =    -75.7278816037 Error = 1.15e-08 FLOPS = 6.03e+09 Tdav = 0.21 T = 1.45
#  <-- Site =   14-  15 .. Mmps =  500 Ndav =   3 E =    -75.7278818527 Error = 2.31e-08 FLOPS = 6.04e+09 Tdav = 0.27 T = 2.09
#  <-- Site =   13-  14 .. Mmps =  500 Ndav =   3 E =    -75.7278822641 Error = 3.73e-08 FLOPS = 6.12e+09 Tdav = 0.34 T = 2.83
#  <-- Site =   12-  13 .. Mmps =  500 Ndav =   3 E =    -75.7278831562 Error = 8.81e-08 FLOPS = 6.27e+09 Tdav = 0.37 T = 6.08
#  <-- Site =   11-  12 .. Mmps =  500 Ndav =   3 E =    -75.7278842022 Error = 1.55e-07 FLOPS = 6.42e+09 Tdav = 0.38 T = 3.81
#  <-- Site =   10-  11 .. Mmps =  500 Ndav =   3 E =    -75.7278870423 Error = 5.16e-07 FLOPS = 6.57e+09 Tdav = 0.33 T = 1.84
#  <-- Site =    9-  10 .. Mmps =  500 Ndav =   4 E =    -75.7278941299 Error = 1.53e-06 FLOPS = 6.90e+09 Tdav = 0.38 T = 1.71
#  <-- Site =    8-   9 .. Mmps =  500 Ndav =   4 E =    -75.7278963607 Error = 1.78e-06 FLOPS = 4.19e+09 Tdav = 0.54 T = 1.97
#  <-- Site =    7-   8 .. Mmps =  500 Ndav =   4 E =    -75.7279044250 Error = 2.50e-06 FLOPS = 3.82e+09 Tdav = 0.49 T = 2.37
#  <-- Site =    6-   7 .. Mmps =  500 Ndav =   5 E =    -75.7279346950 Error = 5.06e-06 FLOPS = 6.96e+09 Tdav = 0.33 T = 1.40
#  <-- Site =    5-   6 .. Mmps =  500 Ndav =   6 E =    -75.7279905032 Error = 1.65e-05 FLOPS = 5.71e+09 Tdav = 0.33 T = 1.09
#  <-- Site =    4-   5 .. Mmps =  500 Ndav =   4 E =    -75.7279133365 Error = 1.85e-07 FLOPS = 2.61e+09 Tdav = 0.10 T = 0.49
#  <-- Site =    3-   4 .. Mmps =  500 Ndav =   1 E =    -75.7279133364 Error = 8.24e-08 FLOPS = 9.12e+08 Tdav = 0.01 T = 0.28
#  <-- Site =    2-   3 .. Mmps =  500 Ndav =   1 E =    -75.7279133364 Error = 5.13e-10 FLOPS = 6.37e+08 Tdav = 0.00 T = 0.15
#  <-- Site =    1-   2 .. Mmps =  114 Ndav =   1 E =    -75.7279133364 Error = 2.53e-20 FLOPS = 6.61e+08 Tdav = 0.00 T = 0.11
#  <-- Site =    0-   1 .. Mmps =   17 Ndav =   1 E =    -75.7279133364 Error = 1.37e-22 FLOPS = 3.19e+07 Tdav = 0.00 T = 0.02
# Time elapsed =    153.350 | E =     -75.7279905032 | DE = -1.04e-04 | DW = 1.65e-05
# Time sweep =       31.242 | 22.4 GFLOP/SWP
#  | Dmem = 26.8 MB (1%) | Imem = 3.30 MB (96%) | Hmem = 579 MB | Wmem = 242 KB | Pmem = 20.4 MB
#  | Tread = 0.443 | Twrite = 0.629 | Tfpread = 0.441 | Tfpwrite = 0.624 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 264 MB | cpsd = 215 MB
#  | Trot = 0.938 | Tctr = 0.011 | Tint = 0.009 | Tmid = 0.000 | Tdctr = 0.014 | Tdiag = 0.130 | Tinfo = 0.260
#  | Teff = 19.693 | Tprt = 4.718 | Teig = 4.345 | Tblk = 29.192 | Tmve = 1.895 | Tdm = 0.223 | Tsplt = 0.098 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =    8 | Direction =  forward | Bond dimension =  750 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  --> Site =    0-   1 .. Mmps =    3 Ndav =   1 E =    -75.7279133364 Error = 0.00e+00 FLOPS = 1.73e+07 Tdav = 0.00 T = 0.01
#  --> Site =    1-   2 .. Mmps =   10 Ndav =   1 E =    -75.7279133364 Error = 0.00e+00 FLOPS = 6.30e+08 Tdav = 0.00 T = 0.07
#  --> Site =    2-   3 .. Mmps =   35 Ndav =   1 E =    -75.7279133364 Error = 0.00e+00 FLOPS = 6.49e+08 Tdav = 0.00 T = 0.10
#  --> Site =    3-   4 .. Mmps =  126 Ndav =   1 E =    -75.7279133364 Error = 0.00e+00 FLOPS = 9.28e+08 Tdav = 0.01 T = 0.22
#  --> Site =    4-   5 .. Mmps =  421 Ndav =   1 E =    -75.7279133364 Error = 0.00e+00 FLOPS = 2.11e+09 Tdav = 0.03 T = 0.36
#  --> Site =    5-   6 .. Mmps =  750 Ndav =   6 E =    -75.7279905058 Error = 1.40e-06 FLOPS = 5.71e+09 Tdav = 0.33 T = 1.04
#  --> Site =    6-   7 .. Mmps =  750 Ndav =   5 E =    -75.7280288171 Error = 1.35e-06 FLOPS = 7.77e+09 Tdav = 0.59 T = 2.04
#  --> Site =    7-   8 .. Mmps =  750 Ndav =   5 E =    -75.7280746779 Error = 7.40e-07 FLOPS = 8.06e+09 Tdav = 0.64 T = 2.23
#  --> Site =    8-   9 .. Mmps =  750 Ndav =   4 E =    -75.7281225653 Error = 5.97e-07 FLOPS = 4.73e+09 Tdav = 1.03 T = 3.62
#  --> Site =    9-  10 .. Mmps =  750 Ndav =   4 E =    -75.7281605371 Error = 5.28e-07 FLOPS = 8.37e+09 Tdav = 0.66 T = 2.91
#  --> Site =   10-  11 .. Mmps =  750 Ndav =   4 E =    -75.7281864144 Error = 3.50e-07 FLOPS = 7.85e+09 Tdav = 0.80 T = 3.09
#  --> Site =   11-  12 .. Mmps =  750 Ndav =   4 E =    -75.7282047508 Error = 1.92e-07 FLOPS = 7.74e+09 Tdav = 0.92 T = 5.50
#  --> Site =   12-  13 .. Mmps =  750 Ndav =   3 E =    -75.7282118759 Error = 1.38e-07 FLOPS = 7.55e+09 Tdav = 0.66 T = 7.98
#  --> Site =   13-  14 .. Mmps =  750 Ndav =   3 E =    -75.7282155349 Error = 6.74e-08 FLOPS = 7.54e+09 Tdav = 0.60 T = 4.20
#  --> Site =   14-  15 .. Mmps =  750 Ndav =   3 E =    -75.7282174239 Error = 5.27e-08 FLOPS = 4.07e+09 Tdav = 0.84 T = 4.77
#  --> Site =   15-  16 .. Mmps =  750 Ndav =   3 E =    -75.7282183509 Error = 4.31e-08 FLOPS = 6.95e+09 Tdav = 0.37 T = 2.25
#  --> Site =   16-  17 .. Mmps =  750 Ndav =   3 E =    -75.7282186451 Error = 1.32e-08 FLOPS = 5.76e+09 Tdav = 0.26 T = 1.79
#  --> Site =   17-  18 .. Mmps =  750 Ndav =   2 E =    -75.7282187353 Error = 7.57e-09 FLOPS = 4.78e+09 Tdav = 0.12 T = 1.40
#  --> Site =   18-  19 .. Mmps =  750 Ndav =   2 E =    -75.7282187395 Error = 2.89e-09 FLOPS = 3.43e+09 Tdav = 0.07 T = 0.92
#  --> Site =   19-  20 .. Mmps =  750 Ndav =   2 E =    -75.7282187406 Error = 1.45e-09 FLOPS = 2.23e+09 Tdav = 0.04 T = 0.66
#  --> Site =   20-  21 .. Mmps =  750 Ndav =   2 E =    -75.7282187410 Error = 3.01e-10 FLOPS = 1.44e+09 Tdav = 0.02 T = 0.43
#  --> Site =   21-  22 .. Mmps =  750 Ndav =   2 E =    -75.7282187494 Error = 4.14e-11 FLOPS = 9.74e+08 Tdav = 0.02 T = 0.35
#  --> Site =   22-  23 .. Mmps =  476 Ndav =   1 E =    -75.7282187494 Error = 3.64e-21 FLOPS = 7.20e+08 Tdav = 0.00 T = 0.21
#  --> Site =   23-  24 .. Mmps =  100 Ndav =   1 E =    -75.7282187494 Error = 2.12e-20 FLOPS = 5.54e+08 Tdav = 0.00 T = 0.08
#  --> Site =   24-  25 .. Mmps =   13 Ndav =   1 E =    -75.7282187494 Error = 6.46e-21 FLOPS = 2.47e+07 Tdav = 0.00 T = 0.02
# Time elapsed =    199.782 | E =     -75.7282187494 | DE = -2.28e-04 | DW = 1.40e-06
# Time sweep =       46.432 | 49.7 GFLOP/SWP
#  | Dmem = 54.3 MB (1%) | Imem = 3.41 MB (96%) | Hmem = 908 MB | Wmem = 386 KB | Pmem = 31.2 MB
#  | Tread = 1.369 | Twrite = 1.375 | Tfpread = 1.363 | Tfpwrite = 1.370 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 546 MB | cpsd = 437 MB
#  | Trot = 1.924 | Tctr = 0.022 | Tint = 0.010 | Tmid = 0.000 | Tdctr = 0.961 | Tdiag = 0.165 | Tinfo = 0.572
#  | Teff = 25.924 | Tprt = 7.634 | Teig = 8.021 | Tblk = 42.283 | Tmve = 3.984 | Tdm = 0.402 | Tsplt = 0.159 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =    9 | Direction = backward | Bond dimension =  750 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  <-- Site =   24-  25 .. Mmps =    3 Ndav =   1 E =    -75.7282187494 Error = 0.00e+00 FLOPS = 2.10e+07 Tdav = 0.00 T = 0.01
#  <-- Site =   23-  24 .. Mmps =   10 Ndav =   1 E =    -75.7282187494 Error = 0.00e+00 FLOPS = 5.54e+08 Tdav = 0.00 T = 0.05
#  <-- Site =   22-  23 .. Mmps =   31 Ndav =   1 E =    -75.7282187494 Error = 0.00e+00 FLOPS = 7.25e+08 Tdav = 0.00 T = 0.13
#  <-- Site =   21-  22 .. Mmps =   81 Ndav =   1 E =    -75.7282187494 Error = 0.00e+00 FLOPS = 8.47e+08 Tdav = 0.01 T = 0.24
#  <-- Site =   20-  21 .. Mmps =  194 Ndav =   1 E =    -75.7282187494 Error = 0.00e+00 FLOPS = 1.31e+09 Tdav = 0.01 T = 0.33
#  <-- Site =   19-  20 .. Mmps =  445 Ndav =   2 E =    -75.7282187504 Error = 0.00e+00 FLOPS = 2.14e+09 Tdav = 0.04 T = 0.53
#  <-- Site =   18-  19 .. Mmps =  750 Ndav =   2 E =    -75.7282187520 Error = 9.83e-13 FLOPS = 2.12e+09 Tdav = 0.12 T = 0.99
#  <-- Site =   17-  18 .. Mmps =  750 Ndav =   2 E =    -75.7282187584 Error = 1.33e-10 FLOPS = 3.16e+09 Tdav = 0.20 T = 2.49
#  <-- Site =   16-  17 .. Mmps =  750 Ndav =   2 E =    -75.7282187840 Error = 8.12e-10 FLOPS = 5.71e+09 Tdav = 0.21 T = 2.29
#  <-- Site =   15-  16 .. Mmps =  750 Ndav =   2 E =    -75.7282189000 Error = 3.36e-09 FLOPS = 6.82e+09 Tdav = 0.30 T = 2.64
#  <-- Site =   14-  15 .. Mmps =  750 Ndav =   3 E =    -75.7282191096 Error = 1.08e-08 FLOPS = 7.88e+09 Tdav = 0.63 T = 4.02
#  <-- Site =   13-  14 .. Mmps =  750 Ndav =   3 E =    -75.7282194546 Error = 2.21e-08 FLOPS = 6.67e+09 Tdav = 1.03 T = 7.12
#  <-- Site =   12-  13 .. Mmps =  750 Ndav =   3 E =    -75.7282201965 Error = 3.87e-08 FLOPS = 8.39e+09 Tdav = 0.89 T = 7.96
#  <-- Site =   11-  12 .. Mmps =  750 Ndav =   3 E =    -75.7282216415 Error = 5.90e-08 FLOPS = 8.62e+09 Tdav = 0.92 T = 8.87
#  <-- Site =   10-  11 .. Mmps =  750 Ndav =   3 E =    -75.7282269952 Error = 1.89e-07 FLOPS = 8.78e+09 Tdav = 0.80 T = 3.86
#  <-- Site =    9-  10 .. Mmps =  750 Ndav =   4 E =    -75.7282370875 Error = 4.83e-07 FLOPS = 5.20e+09 Tdav = 1.61 T = 5.12
#  <-- Site =    8-   9 .. Mmps =  750 Ndav =   4 E =    -75.7282479706 Error = 7.04e-07 FLOPS = 8.90e+09 Tdav = 0.86 T = 3.35
#  <-- Site =    7-   8 .. Mmps =  750 Ndav =   4 E =    -75.7282720747 Error = 1.31e-06 FLOPS = 9.13e+09 Tdav = 0.71 T = 2.98
#  <-- Site =    6-   7 .. Mmps =  750 Ndav =   5 E =    -75.7283208565 Error = 2.39e-06 FLOPS = 9.17e+09 Tdav = 0.81 T = 2.81
#  <-- Site =    5-   6 .. Mmps =  750 Ndav =   7 E =    -75.7283283738 Error = 2.06e-06 FLOPS = 4.60e+09 Tdav = 0.84 T = 2.11
#  <-- Site =    4-   5 .. Mmps =  750 Ndav =   3 E =    -75.7283189532 Error = 6.21e-08 FLOPS = 1.87e+09 Tdav = 0.19 T = 1.19
#  <-- Site =    3-   4 .. Mmps =  750 Ndav =   1 E =    -75.7283189531 Error = 5.46e-08 FLOPS = 1.04e+09 Tdav = 0.03 T = 0.72
#  <-- Site =    2-   3 .. Mmps =  750 Ndav =   1 E =    -75.7283189531 Error = 1.41e-12 FLOPS = 4.81e+08 Tdav = 0.01 T = 0.38
#  <-- Site =    1-   2 .. Mmps =  115 Ndav =   1 E =    -75.7283189531 Error = 2.46e-20 FLOPS = 1.65e+08 Tdav = 0.02 T = 0.30
#  <-- Site =    0-   1 .. Mmps =   16 Ndav =   1 E =    -75.7283189531 Error = 9.50e-23 FLOPS = 3.44e+07 Tdav = 0.00 T = 0.02
# Time elapsed =    260.462 | E =     -75.7283283738 | DE = -1.10e-04 | DW = 2.39e-06
# Time sweep =       60.680 | 67.8 GFLOP/SWP
#  | Dmem = 61.7 MB (1%) | Imem = 3.72 MB (96%) | Hmem = 1.26 GB | Wmem = 528 KB | Pmem = 44.4 MB
#  | Tread = 0.856 | Twrite = 1.461 | Tfpread = 0.854 | Tfpwrite = 1.455 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 583 MB | cpsd = 472 MB
#  | Trot = 1.979 | Tctr = 0.017 | Tint = 0.011 | Tmid = 0.000 | Tdctr = 0.017 | Tdiag = 0.199 | Tinfo = 0.373
#  | Teff = 33.386 | Tprt = 12.049 | Teig = 10.269 | Tblk = 56.584 | Tmve = 3.937 | Tdm = 0.538 | Tsplt = 0.210 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =   10 | Direction =  forward | Bond dimension =  750 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  --> Site =    0-   1 .. Mmps =    3 Ndav =   1 E =    -75.7283189531 Error = 0.00e+00 FLOPS = 1.76e+07 Tdav = 0.00 T = 0.01
#  --> Site =    1-   2 .. Mmps =   10 Ndav =   1 E =    -75.7283189531 Error = 0.00e+00 FLOPS = 9.16e+08 Tdav = 0.00 T = 0.12
#  --> Site =    2-   3 .. Mmps =   35 Ndav =   1 E =    -75.7283189531 Error = 0.00e+00 FLOPS = 1.00e+09 Tdav = 0.01 T = 0.14
#  --> Site =    3-   4 .. Mmps =  126 Ndav =   1 E =    -75.7283189531 Error = 0.00e+00 FLOPS = 1.36e+09 Tdav = 0.02 T = 0.33
#  --> Site =    4-   5 .. Mmps =  421 Ndav =   1 E =    -75.7283189531 Error = 0.00e+00 FLOPS = 2.64e+09 Tdav = 0.04 T = 0.54
#  --> Site =    5-   6 .. Mmps =  750 Ndav =   4 E =    -75.7283283754 Error = 2.60e-06 FLOPS = 6.53e+09 Tdav = 0.34 T = 1.30
#  --> Site =    6-   7 .. Mmps =  750 Ndav =   4 E =    -75.7283309384 Error = 3.28e-06 FLOPS = 8.74e+09 Tdav = 0.68 T = 2.63
#  --> Site =    7-   8 .. Mmps =  750 Ndav =   4 E =    -75.7283268711 Error = 1.87e-06 FLOPS = 8.90e+09 Tdav = 0.71 T = 2.94
#  --> Site =    8-   9 .. Mmps =  750 Ndav =   4 E =    -75.7283266184 Error = 1.24e-06 FLOPS = 6.66e+09 Tdav = 1.14 T = 4.24
#  --> Site =    9-  10 .. Mmps =  750 Ndav =   4 E =    -75.7283277405 Error = 1.13e-06 FLOPS = 9.05e+09 Tdav = 0.95 T = 4.06
#  --> Site =   10-  11 .. Mmps =  750 Ndav =   3 E =    -75.7283275204 Error = 6.48e-07 FLOPS = 8.75e+09 Tdav = 0.86 T = 3.93
#  --> Site =   11-  12 .. Mmps =  750 Ndav =   3 E =    -75.7283280022 Error = 3.19e-07 FLOPS = 7.68e+09 Tdav = 1.12 T = 9.04
#  --> Site =   12-  13 .. Mmps =  750 Ndav =   3 E =    -75.7283281752 Error = 1.97e-07 FLOPS = 8.56e+09 Tdav = 0.97 T = 8.13
#  --> Site =   13-  14 .. Mmps =  750 Ndav =   3 E =    -75.7283280980 Error = 9.13e-08 FLOPS = 8.46e+09 Tdav = 0.89 T = 7.24
#  --> Site =   14-  15 .. Mmps =  750 Ndav =   3 E =    -75.7283280734 Error = 7.28e-08 FLOPS = 7.93e+09 Tdav = 0.71 T = 4.26
#  --> Site =   15-  16 .. Mmps =  750 Ndav =   2 E =    -75.7283280627 Error = 5.47e-08 FLOPS = 7.18e+09 Tdav = 0.33 T = 3.20
#  --> Site =   16-  17 .. Mmps =  750 Ndav =   2 E =    -75.7283279716 Error = 1.56e-08 FLOPS = 4.51e+09 Tdav = 0.31 T = 3.85
#  --> Site =   17-  18 .. Mmps =  750 Ndav =   2 E =    -75.7283279548 Error = 8.39e-09 FLOPS = 3.92e+09 Tdav = 0.19 T = 2.01
#  --> Site =   18-  19 .. Mmps =  750 Ndav =   1 E =    -75.7283279489 Error = 3.24e-09 FLOPS = 2.44e+09 Tdav = 0.06 T = 1.22
#  --> Site =   19-  20 .. Mmps =  750 Ndav =   1 E =    -75.7283279466 Error = 1.57e-09 FLOPS = 2.11e+09 Tdav = 0.02 T = 0.78
#  --> Site =   20-  21 .. Mmps =  750 Ndav =   1 E =    -75.7283279455 Error = 3.20e-10 FLOPS = 1.00e+09 Tdav = 0.02 T = 0.65
#  --> Site =   21-  22 .. Mmps =  750 Ndav =   1 E =    -75.7283279454 Error = 4.23e-11 FLOPS = 7.96e+08 Tdav = 0.01 T = 0.50
#  --> Site =   22-  23 .. Mmps =  482 Ndav =   1 E =    -75.7283279454 Error = 3.56e-21 FLOPS = 5.53e+08 Tdav = 0.01 T = 0.36
#  --> Site =   23-  24 .. Mmps =  102 Ndav =   1 E =    -75.7283279454 Error = 2.18e-21 FLOPS = 4.61e+08 Tdav = 0.00 T = 0.14
#  --> Site =   24-  25 .. Mmps =   13 Ndav =   1 E =    -75.7283279454 Error = 1.81e-20 FLOPS = 3.60e+06 Tdav = 0.01 T = 0.03
# Time elapsed =    322.357 | E =     -75.7283309384 | DE = -2.56e-06 | DW = 3.28e-06
# Time sweep =       61.895 | 68.1 GFLOP/SWP
#  | Dmem = 61.7 MB (1%) | Imem = 3.75 MB (96%) | Hmem = 1.27 GB | Wmem = 527 KB | Pmem = 44.3 MB
#  | Tread = 1.915 | Twrite = 1.830 | Tfpread = 1.910 | Tfpwrite = 1.821 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 551 MB | cpsd = 441 MB
#  | Trot = 2.066 | Tctr = 0.051 | Tint = 0.013 | Tmid = 0.000 | Tdctr = 1.035 | Tdiag = 0.214 | Tinfo = 0.854
#  | Teff = 34.752 | Tprt = 11.448 | Teig = 9.405 | Tblk = 56.715 | Tmve = 4.937 | Tdm = 0.731 | Tsplt = 0.201 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =   11 | Direction = backward | Bond dimension =  750 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  <-- Site =   24-  25 .. Mmps =    3 Ndav =   1 E =    -75.7283279454 Error = 0.00e+00 FLOPS = 2.01e+07 Tdav = 0.00 T = 0.01
#  <-- Site =   23-  24 .. Mmps =   10 Ndav =   1 E =    -75.7283279454 Error = 0.00e+00 FLOPS = 5.10e+08 Tdav = 0.00 T = 0.07
#  <-- Site =   22-  23 .. Mmps =   31 Ndav =   1 E =    -75.7283279454 Error = 0.00e+00 FLOPS = 7.02e+08 Tdav = 0.00 T = 0.16
#  <-- Site =   21-  22 .. Mmps =   81 Ndav =   1 E =    -75.7283279454 Error = 0.00e+00 FLOPS = 4.46e+08 Tdav = 0.02 T = 0.35
#  <-- Site =   20-  21 .. Mmps =  194 Ndav =   1 E =    -75.7283279454 Error = 0.00e+00 FLOPS = 9.86e+08 Tdav = 0.02 T = 0.39
#  <-- Site =   19-  20 .. Mmps =  445 Ndav =   2 E =    -75.7283279466 Error = 0.00e+00 FLOPS = 1.41e+09 Tdav = 0.07 T = 0.68
#  <-- Site =   18-  19 .. Mmps =  750 Ndav =   2 E =    -75.7283279498 Error = 2.23e-12 FLOPS = 3.32e+09 Tdav = 0.08 T = 1.02
#  <-- Site =   17-  18 .. Mmps =  750 Ndav =   2 E =    -75.7283279556 Error = 1.58e-10 FLOPS = 2.79e+09 Tdav = 0.27 T = 2.55
#  <-- Site =   16-  17 .. Mmps =  750 Ndav =   2 E =    -75.7283279812 Error = 9.10e-10 FLOPS = 5.51e+09 Tdav = 0.25 T = 3.18
#  <-- Site =   15-  16 .. Mmps =  750 Ndav =   2 E =    -75.7283281146 Error = 3.98e-09 FLOPS = 5.76e+09 Tdav = 0.41 T = 3.25
#  <-- Site =   14-  15 .. Mmps =  750 Ndav =   2 E =    -75.7283282616 Error = 1.27e-08 FLOPS = 6.77e+09 Tdav = 0.55 T = 4.89
#  <-- Site =   13-  14 .. Mmps =  750 Ndav =   3 E =    -75.7283284869 Error = 2.57e-08 FLOPS = 8.69e+09 Tdav = 0.86 T = 7.45
#  <-- Site =   12-  13 .. Mmps =  750 Ndav =   3 E =    -75.7283290563 Error = 5.28e-08 FLOPS = 8.53e+09 Tdav = 0.97 T = 8.75
#  <-- Site =   11-  12 .. Mmps =  750 Ndav =   3 E =    -75.7283298183 Error = 8.40e-08 FLOPS = 8.70e+09 Tdav = 0.98 T = 8.40
#  <-- Site =   10-  11 .. Mmps =  750 Ndav =   3 E =    -75.7283318428 Error = 2.78e-07 FLOPS = 8.57e+09 Tdav = 0.87 T = 3.94
#  <-- Site =    9-  10 .. Mmps =  750 Ndav =   3 E =    -75.7283352731 Error = 6.34e-07 FLOPS = 6.45e+09 Tdav = 0.99 T = 5.02
#  <-- Site =    8-   9 .. Mmps =  750 Ndav =   4 E =    -75.7283367383 Error = 7.31e-07 FLOPS = 8.78e+09 Tdav = 0.86 T = 3.33
#  <-- Site =    7-   8 .. Mmps =  750 Ndav =   4 E =    -75.7283416559 Error = 1.34e-06 FLOPS = 8.93e+09 Tdav = 0.71 T = 2.97
#  <-- Site =    6-   7 .. Mmps =  750 Ndav =   4 E =    -75.7283513281 Error = 2.59e-06 FLOPS = 9.01e+09 Tdav = 0.66 T = 2.70
#  <-- Site =    5-   6 .. Mmps =  750 Ndav =   5 E =    -75.7283489405 Error = 2.09e-06 FLOPS = 3.68e+09 Tdav = 0.75 T = 2.46
#  <-- Site =    4-   5 .. Mmps =  750 Ndav =   3 E =    -75.7283393442 Error = 6.23e-08 FLOPS = 3.17e+09 Tdav = 0.11 T = 1.04
#  <-- Site =    3-   4 .. Mmps =  750 Ndav =   1 E =    -75.7283393442 Error = 5.47e-08 FLOPS = 1.47e+09 Tdav = 0.02 T = 0.43
#  <-- Site =    2-   3 .. Mmps =  750 Ndav =   1 E =    -75.7283393442 Error = 1.54e-12 FLOPS = 1.01e+09 Tdav = 0.01 T = 0.24
#  <-- Site =    1-   2 .. Mmps =  114 Ndav =   1 E =    -75.7283393442 Error = 8.39e-21 FLOPS = 8.75e+08 Tdav = 0.00 T = 0.17
#  <-- Site =    0-   1 .. Mmps =   15 Ndav =   1 E =    -75.7283393442 Error = 5.09e-21 FLOPS = 2.89e+07 Tdav = 0.00 T = 0.02
# Time elapsed =    386.117 | E =     -75.7283513281 | DE = -2.04e-05 | DW = 2.59e-06
# Time sweep =       63.760 | 64.9 GFLOP/SWP
#  | Dmem = 61.1 MB (1%) | Imem = 3.78 MB (96%) | Hmem = 1.26 GB | Wmem = 527 KB | Pmem = 44.3 MB
#  | Tread = 1.025 | Twrite = 2.015 | Tfpread = 1.023 | Tfpwrite = 2.008 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 579 MB | cpsd = 469 MB
#  | Trot = 2.248 | Tctr = 0.020 | Tint = 0.027 | Tmid = 0.000 | Tdctr = 0.032 | Tdiag = 0.232 | Tinfo = 0.419
#  | Teff = 35.424 | Tprt = 12.531 | Teig = 9.475 | Tblk = 58.609 | Tmve = 4.874 | Tdm = 0.798 | Tsplt = 0.221 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =   12 | Direction =  forward | Bond dimension = 1000 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  --> Site =    0-   1 .. Mmps =    3 Ndav =   1 E =    -75.7283393442 Error = 0.00e+00 FLOPS = 3.25e+07 Tdav = 0.00 T = 0.01
#  --> Site =    1-   2 .. Mmps =   10 Ndav =   1 E =    -75.7283393442 Error = 0.00e+00 FLOPS = 8.91e+08 Tdav = 0.00 T = 0.11
#  --> Site =    2-   3 .. Mmps =   35 Ndav =   1 E =    -75.7283393442 Error = 0.00e+00 FLOPS = 9.84e+08 Tdav = 0.01 T = 0.15
#  --> Site =    3-   4 .. Mmps =  126 Ndav =   1 E =    -75.7283393442 Error = 0.00e+00 FLOPS = 1.44e+09 Tdav = 0.02 T = 0.33
#  --> Site =    4-   5 .. Mmps =  421 Ndav =   1 E =    -75.7283393442 Error = 0.00e+00 FLOPS = 3.09e+09 Tdav = 0.04 T = 0.56
#  --> Site =    5-   6 .. Mmps = 1000 Ndav =   5 E =    -75.7283489409 Error = 1.27e-07 FLOPS = 6.81e+09 Tdav = 0.41 T = 1.35
#  --> Site =    6-   7 .. Mmps = 1000 Ndav =   5 E =    -75.7283655946 Error = 1.18e-06 FLOPS = 9.51e+09 Tdav = 1.12 T = 3.72
#  --> Site =    7-   8 .. Mmps = 1000 Ndav =   4 E =    -75.7283799617 Error = 7.65e-07 FLOPS = 9.54e+09 Tdav = 1.08 T = 4.73
#  --> Site =    8-   9 .. Mmps = 1000 Ndav =   4 E =    -75.7283925464 Error = 5.41e-07 FLOPS = 9.75e+09 Tdav = 1.26 T = 5.23
#  --> Site =    9-  10 .. Mmps = 1000 Ndav =   4 E =    -75.7284034409 Error = 5.04e-07 FLOPS = 9.75e+09 Tdav = 1.44 T = 4.98
#  --> Site =   10-  11 .. Mmps = 1000 Ndav =   4 E =    -75.7284117667 Error = 3.34e-07 FLOPS = 6.84e+09 Tdav = 2.34 T = 7.27
#  --> Site =   11-  12 .. Mmps = 1000 Ndav =   3 E =    -75.7284155318 Error = 1.55e-07 FLOPS = 9.58e+09 Tdav = 1.43 T = 9.77
#  --> Site =   12-  13 .. Mmps = 1000 Ndav =   3 E =    -75.7284173721 Error = 1.08e-07 FLOPS = 9.40e+09 Tdav = 1.43 T = 11.99
#  --> Site =   13-  14 .. Mmps = 1000 Ndav =   3 E =    -75.7284183239 Error = 5.68e-08 FLOPS = 9.49e+09 Tdav = 1.26 T = 9.00
#  --> Site =   14-  15 .. Mmps = 1000 Ndav =   3 E =    -75.7284188841 Error = 4.16e-08 FLOPS = 8.93e+09 Tdav = 1.01 T = 6.45
#  --> Site =   15-  16 .. Mmps = 1000 Ndav =   2 E =    -75.7284190260 Error = 3.30e-08 FLOPS = 7.84e+09 Tdav = 0.48 T = 4.62
#  --> Site =   16-  17 .. Mmps = 1000 Ndav =   2 E =    -75.7284190332 Error = 1.00e-08 FLOPS = 6.80e+09 Tdav = 0.33 T = 3.10
#  --> Site =   17-  18 .. Mmps = 1000 Ndav =   2 E =    -75.7284190450 Error = 5.38e-09 FLOPS = 5.44e+09 Tdav = 0.23 T = 2.38
#  --> Site =   18-  19 .. Mmps = 1000 Ndav =   2 E =    -75.7284190424 Error = 2.08e-09 FLOPS = 4.26e+09 Tdav = 0.11 T = 1.41
#  --> Site =   19-  20 .. Mmps = 1000 Ndav =   1 E =    -75.7284190400 Error = 9.14e-10 FLOPS = 1.42e+09 Tdav = 0.06 T = 1.14
#  --> Site =   20-  21 .. Mmps = 1000 Ndav =   1 E =    -75.7284190394 Error = 1.62e-10 FLOPS = 9.08e+08 Tdav = 0.03 T = 1.13
#  --> Site =   21-  22 .. Mmps = 1000 Ndav =   1 E =    -75.7284190394 Error = 1.13e-11 FLOPS = 6.56e+08 Tdav = 0.02 T = 1.04
#  --> Site =   22-  23 .. Mmps =  536 Ndav =   1 E =    -75.7284190394 Error = 4.04e-21 FLOPS = 5.38e+08 Tdav = 0.01 T = 0.52
#  --> Site =   23-  24 .. Mmps =   99 Ndav =   1 E =    -75.7284190394 Error = 1.53e-20 FLOPS = 3.82e+08 Tdav = 0.00 T = 0.17
#  --> Site =   24-  25 .. Mmps =   13 Ndav =   1 E =    -75.7284190394 Error = 3.29e-21 FLOPS = 1.34e+07 Tdav = 0.00 T = 0.03
# Time elapsed =    467.485 | E =     -75.7284190450 | DE = -6.77e-05 | DW = 1.18e-06
# Time sweep =       81.368 | 114 GFLOP/SWP
#  | Dmem = 94.8 MB (1%) | Imem = 4.12 MB (96%) | Hmem = 1.70 GB | Wmem = 677 KB | Pmem = 57.5 MB
#  | Tread = 2.618 | Twrite = 2.948 | Tfpread = 2.613 | Tfpwrite = 2.942 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 941 MB | cpsd = 751 MB
#  | Trot = 4.111 | Tctr = 0.035 | Tint = 0.013 | Tmid = 0.000 | Tdctr = 1.709 | Tdiag = 0.247 | Tinfo = 0.693
#  | Teff = 41.250 | Tprt = 16.413 | Teig = 14.112 | Tblk = 73.261 | Tmve = 7.928 | Tdm = 0.812 | Tsplt = 0.347 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =   13 | Direction = backward | Bond dimension = 1000 | Noise =  1.00e-05 | Dav threshold =  1.00e-08
#  <-- Site =   24-  25 .. Mmps =    3 Ndav =   1 E =    -75.7284190394 Error = 0.00e+00 FLOPS = 1.22e+07 Tdav = 0.00 T = 0.01
#  <-- Site =   23-  24 .. Mmps =   10 Ndav =   1 E =    -75.7284190394 Error = 0.00e+00 FLOPS = 4.41e+08 Tdav = 0.00 T = 0.09
#  <-- Site =   22-  23 .. Mmps =   31 Ndav =   1 E =    -75.7284190394 Error = 0.00e+00 FLOPS = 8.98e+08 Tdav = 0.01 T = 0.23
#  <-- Site =   21-  22 .. Mmps =   81 Ndav =   1 E =    -75.7284190394 Error = 0.00e+00 FLOPS = 1.10e+09 Tdav = 0.01 T = 0.33
#  <-- Site =   20-  21 .. Mmps =  213 Ndav =   1 E =    -75.7284190394 Error = 0.00e+00 FLOPS = 1.57e+09 Tdav = 0.02 T = 0.44
#  <-- Site =   19-  20 .. Mmps =  548 Ndav =   2 E =    -75.7284190409 Error = 0.00e+00 FLOPS = 2.80e+09 Tdav = 0.06 T = 0.74
#  <-- Site =   18-  19 .. Mmps = 1000 Ndav =   2 E =    -75.7284190433 Error = 5.83e-13 FLOPS = 4.37e+09 Tdav = 0.11 T = 1.28
#  <-- Site =   17-  18 .. Mmps = 1000 Ndav =   2 E =    -75.7284190494 Error = 4.79e-11 FLOPS = 5.88e+09 Tdav = 0.23 T = 2.51
#  <-- Site =   16-  17 .. Mmps = 1000 Ndav =   2 E =    -75.7284190684 Error = 4.10e-10 FLOPS = 7.00e+09 Tdav = 0.38 T = 3.43
#  <-- Site =   15-  16 .. Mmps = 1000 Ndav =   2 E =    -75.7284191759 Error = 1.35e-09 FLOPS = 4.83e+09 Tdav = 0.92 T = 6.01
# ...
# Time sweep =       41.599 | 48.2 GFLOP/SWP
#  | Dmem = 104 MB (0%) | Imem = 2.59 MB (94%) | Hmem = 1.22 GB | Wmem = 434 KB | Pmem = 0 B
#  | Tread = 2.961 | Twrite = 2.365 | Tfpread = 2.955 | Tfpwrite = 2.358 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 896 MB | cpsd = 718 MB
#  | Trot = 3.494 | Tctr = 0.028 | Tint = 0.010 | Tmid = 0.000 | Tdctr = 1.497 | Tdiag = 0.200 | Tinfo = 0.663
#  | Teff = 27.282 | Tprt = 0.000 | Teig = 6.971 | Tblk = 34.680 | Tmve = 6.748 | Tdm = 0.010 | Tsplt = 0.269 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =   24 | Direction = backward | Bond dimension = 1000 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
#  <-- Site =   25 .. Mmps =    3 Ndav =   1 E =    -75.7284677043 Error = 0.00e+00 FLOPS = 2.74e+04 Tdav = 0.00 T = 0.01
#  <-- Site =   24 .. Mmps =   10 Ndav =   1 E =    -75.7284677043 Error = 0.00e+00 FLOPS = 2.31e+05 Tdav = 0.00 T = 0.01
#  <-- Site =   23 .. Mmps =   31 Ndav =   1 E =    -75.7284677043 Error = 0.00e+00 FLOPS = 3.28e+06 Tdav = 0.00 T = 0.02
#  <-- Site =   22 .. Mmps =   87 Ndav =   1 E =    -75.7284677043 Error = 0.00e+00 FLOPS = 3.60e+07 Tdav = 0.00 T = 0.03
#  <-- Site =   21 .. Mmps =  221 Ndav =   1 E =    -75.7284677043 Error = 7.05e-28 FLOPS = 3.92e+08 Tdav = 0.01 T = 0.10
#  <-- Site =   20 .. Mmps =  400 Ndav =   1 E =    -75.7284677043 Error = 2.34e-26 FLOPS = 1.47e+09 Tdav = 0.02 T = 0.21
#  <-- Site =   19 .. Mmps =  690 Ndav =   1 E =    -75.7284677043 Error = 1.69e-25 FLOPS = 2.29e+09 Tdav = 0.07 T = 0.79
#  <-- Site =   18 .. Mmps =  943 Ndav =   1 E =    -75.7284677043 Error = 9.58e-24 FLOPS = 3.28e+09 Tdav = 0.19 T = 1.99
#  <-- Site =   17 .. Mmps =  959 Ndav =   1 E =    -75.7284677043 Error = 1.26e-22 FLOPS = 4.42e+09 Tdav = 0.25 T = 3.24
#  <-- Site =   16 .. Mmps = 1000 Ndav =   1 E =    -75.7284677043 Error = 4.28e-22 FLOPS = 7.49e+09 Tdav = 0.20 T = 3.11
#  <-- Site =   15 .. Mmps = 1000 Ndav =   1 E =    -75.7284677043 Error = 6.39e-21 FLOPS = 7.44e+09 Tdav = 0.29 T = 3.06
#  <-- Site =   14 .. Mmps = 1000 Ndav =   1 E =    -75.7284677043 Error = 4.05e-21 FLOPS = 8.21e+09 Tdav = 0.31 T = 4.49
#  <-- Site =   13 .. Mmps = 1000 Ndav =   1 E =    -75.7284677043 Error = 7.03e-21 FLOPS = 8.51e+09 Tdav = 0.36 T = 7.80
#  <-- Site =   12 .. Mmps = 1000 Ndav =   2 E =    -75.7284677048 Error = 2.47e-20 FLOPS = 6.82e+09 Tdav = 0.91 T = 11.64
#  <-- Site =   11 .. Mmps = 1000 Ndav =   2 E =    -75.7284677057 Error = 3.42e-20 FLOPS = 8.68e+09 Tdav = 0.68 T = 8.63
#  <-- Site =   10 .. Mmps = 1000 Ndav =   2 E =    -75.7284677096 Error = 7.68e-20 FLOPS = 7.81e+09 Tdav = 0.63 T = 5.43
#  <-- Site =    9 .. Mmps = 1000 Ndav =   2 E =    -75.7284677172 Error = 1.16e-19 FLOPS = 8.81e+09 Tdav = 0.46 T = 3.14
#  <-- Site =    8 .. Mmps = 1000 Ndav =   3 E =    -75.7284677781 Error = 1.96e-19 FLOPS = 8.51e+09 Tdav = 0.56 T = 2.91
#  <-- Site =    7 .. Mmps = 1000 Ndav =   3 E =    -75.7284678610 Error = 8.15e-19 FLOPS = 8.69e+09 Tdav = 0.44 T = 2.52
#  <-- Site =    6 .. Mmps = 1000 Ndav =   3 E =    -75.7284679691 Error = 4.55e-19 FLOPS = 4.74e+09 Tdav = 0.58 T = 2.72
#  <-- Site =    5 .. Mmps =  442 Ndav =   2 E =    -75.7284679695 Error = 4.48e-19 FLOPS = 2.32e+09 Tdav = 0.13 T = 1.71
#  <-- Site =    4 .. Mmps =  191 Ndav =   1 E =    -75.7284679695 Error = 3.78e-19 FLOPS = 4.41e+08 Tdav = 0.02 T = 0.64
#  <-- Site =    3 .. Mmps =   71 Ndav =   1 E =    -75.7284679695 Error = 1.08e-19 FLOPS = 4.52e+07 Tdav = 0.01 T = 0.23
#  <-- Site =    2 .. Mmps =   26 Ndav =   1 E =    -75.7284679695 Error = 1.55e-20 FLOPS = 1.54e+07 Tdav = 0.00 T = 0.05
#  <-- Site =    1 .. Mmps =    7 Ndav =   1 E =    -75.7284679695 Error = 1.10e-37 FLOPS = 2.49e+06 Tdav = 0.00 T = 0.02
#  <-- Site =    0 .. Mmps =    4 Ndav =   1 E =    -75.7284679695 Error = 4.84e-50 FLOPS = 7.05e+04 Tdav = 0.00 T = 0.01
# Time elapsed =   1269.879 | E =     -75.7284679695 | DE = -2.65e-07 | DW = 8.15e-19
# Time sweep =       64.664 | 40.8 GFLOP/SWP
#  | Dmem = 104 MB (0%) | Imem = 2.59 MB (94%) | Hmem = 1.22 GB | Wmem = 434 KB | Pmem = 0 B
#  | Tread = 3.170 | Twrite = 2.818 | Tfpread = 3.165 | Tfpwrite = 2.808 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 897 MB | cpsd = 722 MB
#  | Trot = 3.754 | Tctr = 21.607 | Tint = 0.011 | Tmid = 0.000 | Tdctr = 0.017 | Tdiag = 0.227 | Tinfo = 0.667
#  | Teff = 27.358 | Tprt = 0.000 | Teig = 6.107 | Tblk = 33.921 | Tmve = 30.562 | Tdm = 0.010 | Tsplt = 0.292 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =   25 | Direction =  forward | Bond dimension = 1000 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
#  --> Site =    0 .. Mmps =    3 Ndav =   1 E =    -75.7284679695 Error = 0.00e+00 FLOPS = 6.90e+04 Tdav = 0.00 T = 0.01
#  --> Site =    1 .. Mmps =   10 Ndav =   1 E =    -75.7284679695 Error = 0.00e+00 FLOPS = 1.25e+06 Tdav = 0.00 T = 0.01
#  --> Site =    2 .. Mmps =   35 Ndav =   1 E =    -75.7284679695 Error = 0.00e+00 FLOPS = 1.51e+07 Tdav = 0.00 T = 0.01
#  --> Site =    3 .. Mmps =  126 Ndav =   1 E =    -75.7284679695 Error = 0.00e+00 FLOPS = 4.39e+07 Tdav = 0.01 T = 0.03
#  --> Site =    4 .. Mmps =  403 Ndav =   1 E =    -75.7284679695 Error = 1.66e-20 FLOPS = 4.04e+08 Tdav = 0.02 T = 0.11
#  --> Site =    5 .. Mmps = 1000 Ndav =   1 E =    -75.7284679695 Error = 2.07e-17 FLOPS = 3.42e+09 Tdav = 0.04 T = 0.32
#  --> Site =    6 .. Mmps = 1000 Ndav =   1 E =    -75.7284679695 Error = 4.73e-18 FLOPS = 7.34e+09 Tdav = 0.13 T = 0.94
#  --> Site =    7 .. Mmps = 1000 Ndav =   2 E =    -75.7284679720 Error = 2.24e-18 FLOPS = 8.50e+09 Tdav = 0.30 T = 1.43
#  --> Site =    8 .. Mmps = 1000 Ndav =   2 E =    -75.7284679827 Error = 2.75e-18 FLOPS = 8.31e+09 Tdav = 0.38 T = 1.86
#  --> Site =    9 .. Mmps = 1000 Ndav =   3 E =    -75.7284680835 Error = 3.17e-18 FLOPS = 8.76e+09 Tdav = 0.69 T = 2.35
#  --> Site =   10 .. Mmps = 1000 Ndav =   2 E =    -75.7284680933 Error = 4.54e-18 FLOPS = 5.06e+09 Tdav = 0.97 T = 3.06
#  --> Site =   11 .. Mmps = 1000 Ndav =   2 E =    -75.7284681010 Error = 1.68e-18 FLOPS = 8.31e+09 Tdav = 0.71 T = 4.07
#  --> Site =   12 .. Mmps = 1000 Ndav =   2 E =    -75.7284681081 Error = 2.61e-18 FLOPS = 9.01e+09 Tdav = 0.69 T = 7.58
#  --> Site =   13 .. Mmps = 1000 Ndav =   2 E =    -75.7284681121 Error = 1.12e-17 FLOPS = 9.15e+09 Tdav = 0.66 T = 6.03
#  --> Site =   14 .. Mmps = 1000 Ndav =   2 E =    -75.7284681131 Error = 2.84e-18 FLOPS = 8.93e+09 Tdav = 0.56 T = 3.83
#  --> Site =   15 .. Mmps = 1000 Ndav =   2 E =    -75.7284681137 Error = 5.02e-19 FLOPS = 8.32e+09 Tdav = 0.51 T = 2.52
#  --> Site =   16 .. Mmps =  964 Ndav =   2 E =    -75.7284681138 Error = 4.93e-20 FLOPS = 7.79e+09 Tdav = 0.38 T = 2.03
#  --> Site =   17 .. Mmps =  948 Ndav =   2 E =    -75.7284681140 Error = 4.08e-20 FLOPS = 4.55e+09 Tdav = 0.48 T = 2.57
#  --> Site =   18 .. Mmps =  696 Ndav =   1 E =    -75.7284681140 Error = 4.24e-20 FLOPS = 4.35e+09 Tdav = 0.14 T = 1.75
#  --> Site =   19 .. Mmps =  405 Ndav =   1 E =    -75.7284681140 Error = 1.12e-20 FLOPS = 4.04e+09 Tdav = 0.04 T = 0.61
#  --> Site =   20 .. Mmps =  224 Ndav =   1 E =    -75.7284681140 Error = 2.42e-20 FLOPS = 1.64e+09 Tdav = 0.01 T = 0.23
#  --> Site =   21 .. Mmps =   89 Ndav =   1 E =    -75.7284681140 Error = 2.13e-20 FLOPS = 4.01e+08 Tdav = 0.01 T = 0.12
#  --> Site =   22 .. Mmps =   33 Ndav =   1 E =    -75.7284681140 Error = 2.11e-20 FLOPS = 3.61e+07 Tdav = 0.00 T = 0.05
#  --> Site =   23 .. Mmps =   12 Ndav =   1 E =    -75.7284681140 Error = 8.85e-21 FLOPS = 6.49e+06 Tdav = 0.00 T = 0.02
#  --> Site =   24 .. Mmps =    4 Ndav =   1 E =    -75.7284681140 Error = 3.33e-21 FLOPS = 4.39e+05 Tdav = 0.00 T = 0.01
#  --> Site =   25 .. Mmps =    3 Ndav =   1 E =    -75.7284681140 Error = 0.00e+00 FLOPS = 5.05e+04 Tdav = 0.00 T = 0.01
# Time elapsed =   1311.600 | E =     -75.7284681140 | DE = -1.45e-07 | DW = 2.07e-17
# Time sweep =       41.722 | 47.7 GFLOP/SWP
#  | Dmem = 104 MB (0%) | Imem = 2.59 MB (94%) | Hmem = 1.22 GB | Wmem = 434 KB | Pmem = 0 B
#  | Tread = 3.051 | Twrite = 2.479 | Tfpread = 3.046 | Tfpwrite = 2.472 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 896 MB | cpsd = 718 MB
#  | Trot = 3.428 | Tctr = 0.027 | Tint = 0.011 | Tmid = 0.000 | Tdctr = 1.547 | Tdiag = 0.202 | Tinfo = 0.663
#  | Teff = 27.571 | Tprt = 0.000 | Teig = 6.752 | Tblk = 34.750 | Tmve = 6.805 | Tdm = 0.010 | Tsplt = 0.267 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =   26 | Direction = backward | Bond dimension = 1000 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
#  <-- Site =   25 .. Mmps =    3 Ndav =   1 E =    -75.7284681140 Error = 0.00e+00 FLOPS = 3.89e+04 Tdav = 0.00 T = 0.01
#  <-- Site =   24 .. Mmps =   10 Ndav =   1 E =    -75.7284681140 Error = 0.00e+00 FLOPS = 2.91e+05 Tdav = 0.00 T = 0.01
#  <-- Site =   23 .. Mmps =   31 Ndav =   1 E =    -75.7284681140 Error = 0.00e+00 FLOPS = 3.57e+06 Tdav = 0.00 T = 0.01
#  <-- Site =   22 .. Mmps =   87 Ndav =   1 E =    -75.7284681140 Error = 0.00e+00 FLOPS = 3.94e+07 Tdav = 0.00 T = 0.03
#  <-- Site =   21 .. Mmps =  221 Ndav =   1 E =    -75.7284681140 Error = 1.66e-27 FLOPS = 3.99e+08 Tdav = 0.01 T = 0.09
#  <-- Site =   20 .. Mmps =  400 Ndav =   1 E =    -75.7284681140 Error = 2.81e-26 FLOPS = 1.63e+09 Tdav = 0.01 T = 0.21
#  <-- Site =   19 .. Mmps =  690 Ndav =   1 E =    -75.7284681140 Error = 1.38e-25 FLOPS = 3.91e+09 Tdav = 0.04 T = 0.52
#  <-- Site =   18 .. Mmps =  943 Ndav =   1 E =    -75.7284681140 Error = 7.82e-24 FLOPS = 6.55e+09 Tdav = 0.09 T = 1.12
#  <-- Site =   17 .. Mmps =  959 Ndav =   1 E =    -75.7284681140 Error = 1.09e-22 FLOPS = 7.01e+09 Tdav = 0.16 T = 1.68
#  <-- Site =   16 .. Mmps = 1000 Ndav =   1 E =    -75.7284681140 Error = 2.90e-22 FLOPS = 7.32e+09 Tdav = 0.20 T = 2.45
#  <-- Site =   15 .. Mmps = 1000 Ndav =   1 E =    -75.7284681140 Error = 5.48e-21 FLOPS = 5.71e+09 Tdav = 0.37 T = 3.06
#  <-- Site =   14 .. Mmps = 1000 Ndav =   1 E =    -75.7284681140 Error = 4.05e-21 FLOPS = 7.96e+09 Tdav = 0.32 T = 5.96
#  <-- Site =   13 .. Mmps = 1000 Ndav =   1 E =    -75.7284681140 Error = 8.58e-21 FLOPS = 8.36e+09 Tdav = 0.36 T = 6.17
#  <-- Site =   12 .. Mmps = 1000 Ndav =   2 E =    -75.7284681145 Error = 1.78e-20 FLOPS = 8.73e+09 Tdav = 0.71 T = 11.72
#  <-- Site =   11 .. Mmps = 1000 Ndav =   2 E =    -75.7284681152 Error = 3.76e-20 FLOPS = 8.70e+09 Tdav = 0.68 T = 10.21
#  <-- Site =   10 .. Mmps = 1000 Ndav =   2 E =    -75.7284681180 Error = 7.76e-20 FLOPS = 8.72e+09 Tdav = 0.56 T = 3.91
#  <-- Site =    9 .. Mmps = 1000 Ndav =   2 E =    -75.7284681232 Error = 1.01e-19 FLOPS = 8.93e+09 Tdav = 0.45 T = 3.13
#  <-- Site =    8 .. Mmps = 1000 Ndav =   2 E =    -75.7284681381 Error = 2.58e-19 FLOPS = 7.41e+09 Tdav = 0.43 T = 4.29
#  <-- Site =    7 .. Mmps = 1000 Ndav =   3 E =    -75.7284681651 Error = 3.86e-19 FLOPS = 8.61e+09 Tdav = 0.45 T = 2.56
#  <-- Site =    6 .. Mmps = 1000 Ndav =   3 E =    -75.7284681904 Error = 3.92e-19 FLOPS = 8.14e+09 Tdav = 0.34 T = 1.95
#  <-- Site =    5 .. Mmps =  446 Ndav =   1 E =    -75.7284681904 Error = 4.21e-19 FLOPS = 3.70e+09 Tdav = 0.04 T = 0.96
#  <-- Site =    4 .. Mmps =  188 Ndav =   1 E =    -75.7284681904 Error = 4.23e-19 FLOPS = 4.52e+08 Tdav = 0.02 T = 0.59
#  <-- Site =    3 .. Mmps =   74 Ndav =   1 E =    -75.7284681904 Error = 1.11e-19 FLOPS = 4.30e+07 Tdav = 0.01 T = 0.20
#  <-- Site =    2 .. Mmps =   27 Ndav =   1 E =    -75.7284681904 Error = 1.87e-20 FLOPS = 1.51e+07 Tdav = 0.00 T = 0.05
#  <-- Site =    1 .. Mmps =    8 Ndav =   1 E =    -75.7284681904 Error = 3.33e-33 FLOPS = 2.78e+06 Tdav = 0.00 T = 0.02
#  <-- Site =    0 .. Mmps =    2 Ndav =   1 E =    -75.7284681904 Error = 5.20e-34 FLOPS = 1.49e+05 Tdav = 0.00 T = 0.01
# Time elapsed =   1372.679 | E =     -75.7284681904 | DE = -7.64e-08 | DW = 4.23e-19
# Time sweep =       61.079 | 39.2 GFLOP/SWP
#  | Dmem = 104 MB (0%) | Imem = 2.59 MB (94%) | Hmem = 1.22 GB | Wmem = 434 KB | Pmem = 0 B
#  | Tread = 2.884 | Twrite = 2.570 | Tfpread = 2.880 | Tfpwrite = 2.564 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 897 MB | cpsd = 722 MB
#  | Trot = 3.570 | Tctr = 23.663 | Tint = 0.009 | Tmid = 0.000 | Tdctr = 0.013 | Tdiag = 0.189 | Tinfo = 0.599
#  | Teff = 23.247 | Tprt = 0.000 | Teig = 5.264 | Tblk = 28.929 | Tmve = 32.002 | Tdm = 0.009 | Tsplt = 0.253 | Tsvd = 0.000 | Torth = 0.000
#
# Sweep =   27 | Direction =  forward | Bond dimension = 1000 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
#  --> Site =    0 .. Mmps =    3 Ndav =   1 E =    -75.7284681904 Error = 0.00e+00 FLOPS = 1.74e+05 Tdav = 0.00 T = 0.01
#  --> Site =    1 .. Mmps =   10 Ndav =   1 E =    -75.7284681904 Error = 0.00e+00 FLOPS = 2.72e+06 Tdav = 0.00 T = 0.01
#  --> Site =    2 .. Mmps =   35 Ndav =   1 E =    -75.7284681904 Error = 0.00e+00 FLOPS = 1.57e+07 Tdav = 0.00 T = 0.02
#  --> Site =    3 .. Mmps =  126 Ndav =   1 E =    -75.7284681904 Error = 0.00e+00 FLOPS = 4.44e+07 Tdav = 0.01 T = 0.03
#  --> Site =    4 .. Mmps =  403 Ndav =   1 E =    -75.7284681904 Error = 1.51e-20 FLOPS = 4.46e+08 Tdav = 0.02 T = 0.10
#  --> Site =    5 .. Mmps = 1000 Ndav =   1 E =    -75.7284681904 Error = 2.56e-17 FLOPS = 3.61e+09 Tdav = 0.04 T = 0.32
#  --> Site =    6 .. Mmps = 1000 Ndav =   1 E =    -75.7284681904 Error = 3.53e-17 FLOPS = 7.05e+09 Tdav = 0.13 T = 0.95
#  --> Site =    7 .. Mmps = 1000 Ndav =   2 E =    -75.7284681924 Error = 2.03e-18 FLOPS = 8.17e+09 Tdav = 0.32 T = 1.45
#  --> Site =    8 .. Mmps = 1000 Ndav =   2 E =    -75.7284681995 Error = 1.70e-18 FLOPS = 4.62e+09 Tdav = 0.69 T = 2.95
#  --> Site =    9 .. Mmps = 1000 Ndav =   2 E =    -75.7284682176 Error = 3.48e-18 FLOPS = 8.32e+09 Tdav = 0.48 T = 2.53
#  --> Site =   10 .. Mmps = 1000 Ndav =   2 E =    -75.7284682243 Error = 3.39e-18 FLOPS = 8.80e+09 Tdav = 0.56 T = 2.41
#  --> Site =   11 .. Mmps = 1000 Ndav =   2 E =    -75.7284682294 Error = 7.84e-19 FLOPS = 8.78e+09 Tdav = 0.67 T = 3.07
#  --> Site =   12 .. Mmps = 1000 Ndav =   2 E =    -75.7284682339 Error = 5.07e-18 FLOPS = 8.75e+09 Tdav = 0.71 T = 9.13
#  --> Site =   13 .. Mmps = 1000 Ndav =   2 E =    -75.7284682366 Error = 1.08e-18 FLOPS = 9.30e+09 Tdav = 0.65 T = 4.54
#  --> Site =   14 .. Mmps = 1000 Ndav =   2 E =    -75.7284682373 Error = 1.83e-18 FLOPS = 6.05e+09 Tdav = 0.83 T = 4.03
#  --> Site =   15 .. Mmps = 1000 Ndav =   2 E =    -75.7284682375 Error = 6.20e-19 FLOPS = 8.47e+09 Tdav = 0.50 T = 3.86
#  --> Site =   16 .. Mmps =  967 Ndav =   1 E =    -75.7284682375 Error = 5.23e-20 FLOPS = 6.79e+09 Tdav = 0.22 T = 1.94
#  --> Site =   17 .. Mmps =  951 Ndav =   1 E =    -75.7284682375 Error = 3.88e-20 FLOPS = 7.70e+09 Tdav = 0.14 T = 1.47
#  --> Site =   18 .. Mmps =  695 Ndav =   2 E =    -75.7284682376 Error = 4.72e-20 FLOPS = 6.92e+09 Tdav = 0.18 T = 1.17
#  --> Site =   19 .. Mmps =  404 Ndav =   1 E =    -75.7284682376 Error = 2.70e-20 FLOPS = 4.06e+09 Tdav = 0.04 T = 0.68
#  --> Site =   20 .. Mmps =  225 Ndav =   1 E =    -75.7284682376 Error = 2.20e-20 FLOPS = 1.62e+09 Tdav = 0.01 T = 0.24
#  --> Site =   21 .. Mmps =   90 Ndav =   1 E =    -75.7284682376 Error = 2.68e-20 FLOPS = 3.78e+08 Tdav = 0.01 T = 0.12
#  --> Site =   22 .. Mmps =   34 Ndav =   1 E =    -75.7284682376 Error = 9.59e-21 FLOPS = 3.96e+07 Tdav = 0.00 T = 0.05
#  --> Site =   23 .. Mmps =   12 Ndav =   1 E =    -75.7284682376 Error = 1.40e-20 FLOPS = 6.79e+06 Tdav = 0.00 T = 0.02
#  --> Site =   24 .. Mmps =    5 Ndav =   1 E =    -75.7284682376 Error = 3.49e-21 FLOPS = 4.37e+05 Tdav = 0.00 T = 0.01
#  --> Site =   25 .. Mmps =    2 Ndav =   1 E =    -75.7284682376 Error = 0.00e+00 FLOPS = 4.22e+04 Tdav = 0.00 T = 0.01
# Time elapsed =   1413.959 | E =     -75.7284682376 | DE = -4.72e-08 | DW = 3.53e-17
# Time sweep =       41.280 | 44.0 GFLOP/SWP
#  | Dmem = 104 MB (0%) | Imem = 2.59 MB (94%) | Hmem = 1.22 GB | Wmem = 434 KB | Pmem = 0 B
#  | Tread = 2.953 | Twrite = 2.578 | Tfpread = 2.948 | Tfpwrite = 2.572 | Tmporead = 0.000 | Tasync = 0.000
#  | data = 896 MB | cpsd = 718 MB
#  | Trot = 3.546 | Tctr = 0.027 | Tint = 0.010 | Tmid = 0.000 | Tdctr = 1.466 | Tdiag = 0.191 | Tinfo = 0.662
#  | Teff = 27.438 | Tprt = 0.000 | Teig = 6.220 | Tblk = 34.094 | Tmve = 7.013 | Tdm = 0.010 | Tsplt = 0.268 | Tsvd = 0.000 | Torth = 0.000
#
# ATTENTION: DMRG is not converged to desired tolerance of 1.000e-08
# DMRG energy (variational) =  -75.728468237610826

# %% [markdown]
# ## Restarting from backup MPS
#
# We can set the ``restart_dir`` in ``DMRGDriver`` to a different directory name than ``scratch``, so that after each sweep, ``block2`` will store a copy the MPS (int the left canonicalized or right canonicalized form) in the given ``restart_dir`` directory.
#
# We can then restart using the data from this directory when the ``scratch`` folder is removed. To do this, we can copy the
# data from ``restart_dir`` to the ``scratch`` for the new DMRG calculation, and use ``driver.load_mps`` to load the MPS.
#
# Note that for this case, since after each sweep, the MPS is either left canonicalized or right canonicalized, the next sweep direction can be automatically determined without the need to set the ``forward`` parameter in ``driver.dmrg``.
